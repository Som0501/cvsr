# %% [markdown]
# EEE3032 – Computer Vision and Pattern Recognition
# Coursework Assignment
# Prof Miroslaw Bober

# %%
import os
import numpy as np
import cv2
import scipy.io as sio
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import auc, precision_recall_curve, average_precision_score, f1_score, confusion_matrix
import glob  # For file handling
from sklearn.cluster import MiniBatchKMeans  # For codebook
from sklearn.preprocessing import StandardScaler
import shutil  # To clear old descriptors
from sklearn.decomposition import PCA
from sklearn.covariance import EmpiricalCovariance
from skimage.feature import local_binary_pattern

# %%
## Images and Descriptors Location 

DATASET_FOLDER = 'MSRC_ObjCategImageDatabase_v2'
OUT_FOLDER = 'descriptors'
OUT_SUBFOLDER = 'globalHSVhisto'  ## For global HSV
OUT_SUBFOLDER_GRID = 'gridHSV_LBP'  ## For grid + LBP
OUT_SUBFOLDER_BOVW = 'bovw_ORB'  ## Output Folder for BoVW with ORB
FIXED_SIZE = (240, 240)  # Fixed resize for consistency across phases

# %% [markdown]
# # Task 1 : Create Global Color Histogram

# %%
def extract_global_hsv_hist(img, Q):
    img_uint8 = (img * 255).astype(np.uint8)
    hsv = cv2.cvtColor(img_uint8, cv2.COLOR_RGB2HSV)
    h, s, v = cv2.split(hsv)
    h_bins = np.floor((h / 180.0) * Q).astype(int)
    s_bins = np.floor((s / 255.0) * Q).astype(int)
    v_bins = np.floor((v / 255.0) * Q).astype(int)
    hist_h = np.bincount(h_bins.flatten(), minlength=Q)
    hist_s = np.bincount(s_bins.flatten(), minlength=Q)
    hist_v = np.bincount(v_bins.flatten(), minlength=Q)
    hist = np.concatenate([hist_h, hist_s, hist_v])
    norm = np.linalg.norm(hist)
    if norm > 0:
        hist = hist / norm
    return hist

# %%
def compute_and_save_descriptors(Q, dataset_folder, out_folder, out_subfolder):
    # Ensure the output directory exists
    os.makedirs(os.path.join(out_folder, out_subfolder), exist_ok=True)

    # Iterate through all BMP files in the dataset folder using glob
    for img_path in glob.glob(os.path.join(dataset_folder, 'Images', '*.bmp')):
        filename = os.path.basename(img_path)
        print(f"Processing file {filename}")
        img = cv2.imread(img_path).astype(np.float64) / 255.0  # Normalize the image
        fout = os.path.join(out_folder, out_subfolder, filename.replace('.bmp', '.mat'))
        
        # Extract HSV histogram
        F = extract_global_hsv_hist(img, Q)
        
        # Save the descriptor to a .mat file
        sio.savemat(fout, {'F': F})
    print("Successfully Created Global HSV Color Descriptors")

# %%
# Experiment with quantization levels: 4,8,16,32,48
quant_levels = [4,8,16,32,48]
for Q in quant_levels:
    print(f"Testing Q={Q}; expects better color separation but higher compute cost")
    compute_and_save_descriptors(Q, DATASET_FOLDER, OUT_FOLDER, OUT_SUBFOLDER)
# Out:
# Testing Q=4; expects better color separation but higher compute cost
# Processing file 17_15_s.bmp
# Processing file 16_15_s.bmp
# Processing file 14_27_s.bmp
# Processing file 3_2_s.bmp
# Processing file 1_20_s.bmp
# Processing file 8_5_s.bmp
# Processing file 2_12_s.bmp
# Processing file 3_12_s.bmp
# Processing file 18_20_s.bmp
# Processing file 19_20_s.bmp
# Processing file 13_3_s.bmp
# Processing file 18_4_s.bmp
# Processing file 10_2_s.bmp
# Processing file 20_18_s.bmp
# Processing file 17_28_s.bmp
# Processing file 16_28_s.bmp
# Processing file 8_10_s.bmp
# Processing file 9_10_s.bmp
# Processing file 7_18_s.bmp
# Processing file 1_7_s.bmp
# Processing file 9_1_s.bmp
# Processing file 6_18_s.bmp
# Processing file 2_6_s.bmp
# Processing file 11_6_s.bmp
# Processing file 5_17_s.bmp
# Processing file 4_17_s.bmp
# Processing file 12_7_s.bmp
# Processing file 7_25_s.bmp
# Processing file 6_25_s.bmp
# Processing file 12_22_s.bmp
# Processing file 13_22_s.bmp
# Processing file 10_10_s.bmp
# Processing file 11_10_s.bmp
# Processing file 7_27_s.bmp
# Processing file 6_27_s.bmp
# Processing file 12_5_s.bmp
# Processing file 5_15_s.bmp
# Processing file 4_15_s.bmp
# Processing file 11_4_s.bmp
# Processing file 19_2_s.bmp
# Processing file 10_12_s.bmp
# Processing file 11_12_s.bmp
# Processing file 4_9_s.bmp
# Processing file 12_20_s.bmp
# Processing file 13_20_s.bmp
# Processing file 7_8_s.bmp
# Processing file 14_8_s.bmp
# Processing file 8_12_s.bmp
# Processing file 9_12_s.bmp
# Processing file 17_9_s.bmp
# Processing file 5_28_s.bmp
# Processing file 4_28_s.bmp
# Processing file 2_4_s.bmp
# Processing file 1_5_s.bmp
# Processing file 9_3_s.bmp
# Processing file 18_6_s.bmp
# Processing file 13_1_s.bmp
# Processing file 18_22_s.bmp
# Processing file 19_22_s.bmp
# Processing file 15_18_s.bmp
# Processing file 14_18_s.bmp
# Processing file 14_25_s.bmp
# Processing file 17_17_s.bmp
# Processing file 16_17_s.bmp
# Processing file 2_10_s.bmp
# Processing file 3_10_s.bmp
# Processing file 8_7_s.bmp
# Processing file 1_22_s.bmp
# Processing file 5_9_s.bmp
# Processing file 6_8_s.bmp
# Processing file 2_29_s.bmp
# Processing file 13_5_s.bmp
# Processing file 3_29_s.bmp
# Processing file 18_26_s.bmp
# Processing file 19_26_s.bmp
# Processing file 18_2_s.bmp
# Processing file 10_4_s.bmp
# Processing file 1_26_s.bmp
# Processing file 10_32_s.bmp
# Processing file 3_4_s.bmp
# Processing file 2_14_s.bmp
# Processing file 3_14_s.bmp
# Processing file 8_3_s.bmp
# Processing file 17_13_s.bmp
# Processing file 16_13_s.bmp
# Processing file 15_8_s.bmp
# Processing file 15_21_s.bmp
# Processing file 14_21_s.bmp
# Processing file 16_9_s.bmp
# Processing file 12_24_s.bmp
# Processing file 13_24_s.bmp
# Processing file 2_30_s.bmp
# Processing file 3_30_s.bmp
# Processing file 10_16_s.bmp
# Processing file 11_16_s.bmp
# Processing file 5_11_s.bmp
# Processing file 4_11_s.bmp
# Processing file 19_6_s.bmp
# Processing file 7_23_s.bmp
# Processing file 6_23_s.bmp
# Processing file 12_1_s.bmp
# Processing file 1_1_s.bmp
# Processing file 9_7_s.bmp
# Processing file 12_19_s.bmp
# Processing file 13_19_s.bmp
# Processing file 8_16_s.bmp
# Processing file 9_16_s.bmp
# Processing file 2_2_s.bmp
# Processing file 1_3_s.bmp
# Processing file 9_5_s.bmp
# Processing file 8_14_s.bmp
# Processing file 9_14_s.bmp
# Processing file 10_29_s.bmp
# Processing file 11_29_s.bmp
# Processing file 10_14_s.bmp
# Processing file 11_14_s.bmp
# Processing file 8_29_s.bmp
# Processing file 9_29_s.bmp
# Processing file 12_26_s.bmp
# Processing file 13_26_s.bmp
# Processing file 12_3_s.bmp
# Processing file 7_21_s.bmp
# Processing file 6_21_s.bmp
# Processing file 11_2_s.bmp
# Processing file 19_4_s.bmp
# Processing file 5_13_s.bmp
# Processing file 4_13_s.bmp
# Processing file 8_1_s.bmp
# Processing file 18_19_s.bmp
# Processing file 19_19_s.bmp
# Processing file 2_16_s.bmp
# Processing file 3_16_s.bmp
# Processing file 20_9_s.bmp
# Processing file 10_30_s.bmp
# Processing file 3_6_s.bmp
# Processing file 11_30_s.bmp
# Processing file 20_21_s.bmp
# Processing file 1_24_s.bmp
# Processing file 15_23_s.bmp
# Processing file 14_23_s.bmp
# Processing file 17_11_s.bmp
# Processing file 16_11_s.bmp
# Processing file 10_6_s.bmp
# Processing file 1_19_s.bmp
# Processing file 18_24_s.bmp
# Processing file 19_24_s.bmp
# Processing file 8_30_s.bmp
# Processing file 13_7_s.bmp
# Processing file 9_30_s.bmp
# Processing file 5_29_s.bmp
# Processing file 4_29_s.bmp
# Processing file 2_5_s.bmp
# Processing file 9_2_s.bmp
# Processing file 1_4_s.bmp
# Processing file 14_9_s.bmp
# Processing file 8_13_s.bmp
# Processing file 9_13_s.bmp
# Processing file 17_8_s.bmp
# Processing file 10_13_s.bmp
# Processing file 11_13_s.bmp
# Processing file 4_8_s.bmp
# Processing file 12_21_s.bmp
# Processing file 13_21_s.bmp
# Processing file 7_9_s.bmp
# Processing file 7_26_s.bmp
# Processing file 6_26_s.bmp
# Processing file 12_4_s.bmp
# Processing file 5_14_s.bmp
# Processing file 4_14_s.bmp
# Processing file 19_3_s.bmp
# Processing file 11_5_s.bmp
# Processing file 2_11_s.bmp
# Processing file 3_11_s.bmp
# Processing file 8_6_s.bmp
# Processing file 1_23_s.bmp
# Processing file 3_1_s.bmp
# Processing file 15_24_s.bmp
# Processing file 14_24_s.bmp
# Processing file 5_30_s.bmp
# Processing file 4_30_s.bmp
# Processing file 17_16_s.bmp
# Processing file 16_16_s.bmp
# Processing file 15_19_s.bmp
# Processing file 14_19_s.bmp
# Processing file 10_1_s.bmp
# Processing file 18_7_s.bmp
# Processing file 18_23_s.bmp
# Processing file 19_23_s.bmp
# Processing file 17_29_s.bmp
# Processing file 16_29_s.bmp
# Processing file 18_21_s.bmp
# Processing file 19_21_s.bmp
# Processing file 13_2_s.bmp
# Processing file 10_3_s.bmp
# Processing file 18_5_s.bmp
# Processing file 20_19_s.bmp
# Processing file 3_3_s.bmp
# Processing file 1_21_s.bmp
# Processing file 8_4_s.bmp
# Processing file 2_13_s.bmp
# Processing file 3_13_s.bmp
# Processing file 17_14_s.bmp
# Processing file 16_14_s.bmp
# Processing file 14_26_s.bmp
# Processing file 12_23_s.bmp
# Processing file 13_23_s.bmp
# Processing file 10_11_s.bmp
# Processing file 11_11_s.bmp
# Processing file 19_1_s.bmp
# Processing file 11_7_s.bmp
# Processing file 5_16_s.bmp
# Processing file 4_16_s.bmp
# Processing file 17_30_s.bmp
# Processing file 16_30_s.bmp
# Processing file 12_6_s.bmp
# Processing file 7_24_s.bmp
# Processing file 6_24_s.bmp
# Processing file 7_19_s.bmp
# Processing file 6_19_s.bmp
# Processing file 1_6_s.bmp
# Processing file 2_7_s.bmp
# Processing file 8_11_s.bmp
# Processing file 9_11_s.bmp
# Processing file 12_2_s.bmp
# Processing file 7_20_s.bmp
# Processing file 6_20_s.bmp
# Processing file 19_5_s.bmp
# Processing file 11_3_s.bmp
# Processing file 5_12_s.bmp
# Processing file 4_12_s.bmp
# Processing file 10_15_s.bmp
# Processing file 11_15_s.bmp
# Processing file 8_28_s.bmp
# Processing file 9_28_s.bmp
# Processing file 12_27_s.bmp
# Processing file 13_27_s.bmp
# Processing file 8_15_s.bmp
# Processing file 9_15_s.bmp
# Processing file 10_28_s.bmp
# Processing file 11_28_s.bmp
# Processing file 2_3_s.bmp
# Processing file 9_4_s.bmp
# Processing file 1_2_s.bmp
# Processing file 10_7_s.bmp
# Processing file 18_1_s.bmp
# Processing file 1_18_s.bmp
# Processing file 18_25_s.bmp
# Processing file 19_25_s.bmp
# Processing file 13_6_s.bmp
# Processing file 15_22_s.bmp
# Processing file 14_22_s.bmp
# Processing file 17_10_s.bmp
# Processing file 16_10_s.bmp
# Processing file 18_18_s.bmp
# Processing file 19_18_s.bmp
# Processing file 2_17_s.bmp
# Processing file 20_8_s.bmp
# Processing file 3_17_s.bmp
# Processing file 10_31_s.bmp
# Processing file 3_7_s.bmp
# Processing file 1_25_s.bmp
# Processing file 20_20_s.bmp
# Processing file 17_12_s.bmp
# Processing file 16_12_s.bmp
# Processing file 15_9_s.bmp
# Processing file 15_20_s.bmp
# Processing file 14_20_s.bmp
# Processing file 16_8_s.bmp
# Processing file 1_27_s.bmp
# Processing file 3_5_s.bmp
# Processing file 2_15_s.bmp
# Processing file 3_15_s.bmp
# Processing file 8_2_s.bmp
# Processing file 2_28_s.bmp
# Processing file 13_4_s.bmp
# Processing file 3_28_s.bmp
# Processing file 18_27_s.bmp
# Processing file 19_27_s.bmp
# Processing file 10_5_s.bmp
# Processing file 18_3_s.bmp
# Processing file 5_8_s.bmp
# Processing file 6_9_s.bmp
# Processing file 12_18_s.bmp
# Processing file 13_18_s.bmp
# Processing file 8_17_s.bmp
# Processing file 9_17_s.bmp
# Processing file 9_6_s.bmp
# Processing file 2_1_s.bmp
# Processing file 5_10_s.bmp
# Processing file 4_10_s.bmp
# Processing file 19_7_s.bmp
# Processing file 11_1_s.bmp
# Processing file 7_22_s.bmp
# Processing file 6_22_s.bmp
# Processing file 12_25_s.bmp
# Processing file 13_25_s.bmp
# Processing file 10_17_s.bmp
# Processing file 11_17_s.bmp
# Processing file 9_26_s.bmp
# Processing file 7_1_s.bmp
# Processing file 8_26_s.bmp
# Processing file 13_29_s.bmp
# Processing file 12_29_s.bmp
# Processing file 11_26_s.bmp
# Processing file 10_26_s.bmp
# Processing file 13_14_s.bmp
# Processing file 14_1_s.bmp
# Processing file 12_14_s.bmp
# Processing file 6_13_s.bmp
# Processing file 7_13_s.bmp
# Processing file 4_21_s.bmp
# Processing file 5_21_s.bmp
# Processing file 13_30_s.bmp
# Processing file 12_30_s.bmp
# Processing file 3_24_s.bmp
# Processing file 13_8_s.bmp
# Processing file 2_24_s.bmp
# Processing file 20_13_s.bmp
# Processing file 1_16_s.bmp
# Processing file 10_9_s.bmp
# Processing file 14_11_s.bmp
# Processing file 5_4_s.bmp
# Processing file 15_11_s.bmp
# Processing file 16_23_s.bmp
# Processing file 6_5_s.bmp
# Processing file 17_23_s.bmp
# Processing file 15_5_s.bmp
# Processing file 16_4_s.bmp
# Processing file 3_9_s.bmp
# Processing file 19_16_s.bmp
# Processing file 18_16_s.bmp
# Processing file 20_6_s.bmp
# Processing file 3_19_s.bmp
# Processing file 2_19_s.bmp
# Processing file 16_6_s.bmp
# Processing file 15_7_s.bmp
# Processing file 20_4_s.bmp
# Processing file 19_14_s.bmp
# Processing file 18_14_s.bmp
# Processing file 1_29_s.bmp
# Processing file 20_11_s.bmp
# Processing file 1_14_s.bmp
# Processing file 3_26_s.bmp
# Processing file 2_26_s.bmp
# Processing file 19_29_s.bmp
# Processing file 12_32_s.bmp
# Processing file 18_29_s.bmp
# Processing file 16_21_s.bmp
# Processing file 6_7_s.bmp
# Processing file 17_21_s.bmp
# Processing file 14_13_s.bmp
# Processing file 5_6_s.bmp
# Processing file 15_13_s.bmp
# Processing file 13_16_s.bmp
# Processing file 14_3_s.bmp
# Processing file 12_16_s.bmp
# Processing file 9_19_s.bmp
# Processing file 8_19_s.bmp
# Processing file 17_2_s.bmp
# Processing file 11_24_s.bmp
# Processing file 10_24_s.bmp
# Processing file 1_30_s.bmp
# Processing file 4_23_s.bmp
# Processing file 5_23_s.bmp
# Processing file 6_11_s.bmp
# Processing file 9_8_s.bmp
# Processing file 7_11_s.bmp
# Processing file 19_9_s.bmp
# Processing file 11_19_s.bmp
# Processing file 10_19_s.bmp
# Processing file 4_2_s.bmp
# Processing file 19_30_s.bmp
# Processing file 18_30_s.bmp
# Processing file 9_24_s.bmp
# Processing file 7_3_s.bmp
# Processing file 8_24_s.bmp
# Processing file 6_15_s.bmp
# Processing file 7_15_s.bmp
# Processing file 4_27_s.bmp
# Processing file 5_27_s.bmp
# Processing file 17_6_s.bmp
# Processing file 11_20_s.bmp
# Processing file 10_20_s.bmp
# Processing file 13_12_s.bmp
# Processing file 14_7_s.bmp
# Processing file 12_12_s.bmp
# Processing file 9_20_s.bmp
# Processing file 7_7_s.bmp
# Processing file 8_20_s.bmp
# Processing file 4_6_s.bmp
# Processing file 6_28_s.bmp
# Processing file 7_28_s.bmp
# Processing file 19_10_s.bmp
# Processing file 18_10_s.bmp
# Processing file 8_8_s.bmp
# Processing file 16_18_s.bmp
# Processing file 17_18_s.bmp
# Processing file 15_3_s.bmp
# Processing file 16_2_s.bmp
# Processing file 14_17_s.bmp
# Processing file 5_2_s.bmp
# Processing file 15_17_s.bmp
# Processing file 16_25_s.bmp
# Processing file 6_3_s.bmp
# Processing file 17_25_s.bmp
# Processing file 3_22_s.bmp
# Processing file 2_22_s.bmp
# Processing file 20_15_s.bmp
# Processing file 1_10_s.bmp
# Processing file 18_9_s.bmp
# Processing file 16_27_s.bmp
# Processing file 6_1_s.bmp
# Processing file 17_27_s.bmp
# Processing file 14_15_s.bmp
# Processing file 15_15_s.bmp
# Processing file 20_17_s.bmp
# Processing file 1_12_s.bmp
# Processing file 12_34_s.bmp
# Processing file 3_20_s.bmp
# Processing file 2_20_s.bmp
# Processing file 19_12_s.bmp
# Processing file 18_12_s.bmp
# Processing file 20_2_s.bmp
# Processing file 14_28_s.bmp
# Processing file 15_1_s.bmp
# Processing file 4_4_s.bmp
# Processing file 9_22_s.bmp
# Processing file 7_5_s.bmp
# Processing file 8_22_s.bmp
# Processing file 12_8_s.bmp
# Processing file 11_9_s.bmp
# Processing file 4_18_s.bmp
# Processing file 5_18_s.bmp
# Processing file 2_9_s.bmp
# Processing file 4_25_s.bmp
# Processing file 5_25_s.bmp
# Processing file 6_17_s.bmp
# Processing file 1_8_s.bmp
# Processing file 7_17_s.bmp
# Processing file 13_10_s.bmp
# Processing file 14_5_s.bmp
# Processing file 12_10_s.bmp
# Processing file 17_4_s.bmp
# Processing file 11_22_s.bmp
# Processing file 10_22_s.bmp
# Processing file 16_20_s.bmp
# Processing file 6_6_s.bmp
# Processing file 17_20_s.bmp
# Processing file 14_12_s.bmp
# Processing file 15_12_s.bmp
# Processing file 5_7_s.bmp
# Processing file 1_15_s.bmp
# Processing file 20_10_s.bmp
# Processing file 3_27_s.bmp
# Processing file 2_27_s.bmp
# Processing file 19_28_s.bmp
# Processing file 18_28_s.bmp
# Processing file 12_33_s.bmp
# Processing file 20_5_s.bmp
# Processing file 19_15_s.bmp
# Processing file 18_15_s.bmp
# Processing file 1_28_s.bmp
# Processing file 16_7_s.bmp
# Processing file 15_6_s.bmp
# Processing file 11_18_s.bmp
# Processing file 10_18_s.bmp
# Processing file 4_3_s.bmp
# Processing file 7_2_s.bmp
# Processing file 9_25_s.bmp
# Processing file 8_25_s.bmp
# Processing file 19_8_s.bmp
# Processing file 4_22_s.bmp
# Processing file 5_22_s.bmp
# Processing file 6_10_s.bmp
# Processing file 9_9_s.bmp
# Processing file 7_10_s.bmp
# Processing file 14_2_s.bmp
# Processing file 13_17_s.bmp
# Processing file 12_17_s.bmp
# Processing file 9_18_s.bmp
# Processing file 8_18_s.bmp
# Processing file 17_3_s.bmp
# Processing file 11_25_s.bmp
# Processing file 10_25_s.bmp
# Processing file 6_12_s.bmp
# Processing file 7_12_s.bmp
# Processing file 4_20_s.bmp
# Processing file 5_20_s.bmp
# Processing file 17_1_s.bmp
# Processing file 11_27_s.bmp
# Processing file 10_27_s.bmp
# Processing file 13_15_s.bmp
# Processing file 12_15_s.bmp
# Processing file 9_27_s.bmp
# Processing file 8_27_s.bmp
# Processing file 13_28_s.bmp
# Processing file 12_28_s.bmp
# Processing file 4_1_s.bmp
# Processing file 3_8_s.bmp
# Processing file 19_17_s.bmp
# Processing file 18_17_s.bmp
# Processing file 3_18_s.bmp
# Processing file 20_7_s.bmp
# Processing file 2_18_s.bmp
# Processing file 15_4_s.bmp
# Processing file 16_5_s.bmp
# Processing file 14_10_s.bmp
# Processing file 15_10_s.bmp
# Processing file 5_5_s.bmp
# Processing file 16_22_s.bmp
# Processing file 6_4_s.bmp
# Processing file 17_22_s.bmp
# Processing file 12_31_s.bmp
# Processing file 3_25_s.bmp
# Processing file 13_9_s.bmp
# Processing file 2_25_s.bmp
# Processing file 1_17_s.bmp
# Processing file 20_12_s.bmp
# Processing file 10_8_s.bmp
# Processing file 16_1_s.bmp
# Processing file 14_29_s.bmp
# Processing file 19_13_s.bmp
# Processing file 18_13_s.bmp
# Processing file 20_3_s.bmp
# Processing file 1_13_s.bmp
# Processing file 20_16_s.bmp
# Processing file 3_21_s.bmp
# Processing file 2_21_s.bmp
# Processing file 16_26_s.bmp
# Processing file 17_26_s.bmp
# Processing file 14_14_s.bmp
# Processing file 15_14_s.bmp
# Processing file 5_1_s.bmp
# Processing file 14_4_s.bmp
# Processing file 13_11_s.bmp
# Processing file 12_11_s.bmp
# Processing file 17_5_s.bmp
# Processing file 11_23_s.bmp
# Processing file 10_23_s.bmp
# Processing file 14_30_s.bmp
# Processing file 2_8_s.bmp
# Processing file 4_24_s.bmp
# Processing file 5_24_s.bmp
# Processing file 1_9_s.bmp
# Processing file 6_16_s.bmp
# Processing file 7_16_s.bmp
# Processing file 12_9_s.bmp
# Processing file 11_8_s.bmp
# Processing file 4_19_s.bmp
# Processing file 5_19_s.bmp
# Processing file 4_5_s.bmp
# Processing file 7_4_s.bmp
# Processing file 9_23_s.bmp
# Processing file 8_23_s.bmp
# Processing file 6_29_s.bmp
# Processing file 7_29_s.bmp
# Processing file 7_6_s.bmp
# Processing file 9_21_s.bmp
# Processing file 8_21_s.bmp
# Processing file 4_7_s.bmp
# Processing file 17_7_s.bmp
# Processing file 11_21_s.bmp
# Processing file 10_21_s.bmp
# Processing file 14_6_s.bmp
# Processing file 13_13_s.bmp
# Processing file 12_13_s.bmp
# Processing file 6_14_s.bmp
# Processing file 7_14_s.bmp
# Processing file 4_26_s.bmp
# Processing file 5_26_s.bmp
# Processing file 3_23_s.bmp
# Processing file 2_23_s.bmp
# Processing file 1_11_s.bmp
# Processing file 20_14_s.bmp
# Processing file 18_8_s.bmp
# Processing file 14_16_s.bmp
# Processing file 15_16_s.bmp
# Processing file 5_3_s.bmp
# Processing file 16_24_s.bmp
# Processing file 6_2_s.bmp
# Processing file 17_24_s.bmp
# Processing file 6_30_s.bmp
# Processing file 7_30_s.bmp
# Processing file 16_19_s.bmp
# Processing file 17_19_s.bmp
# Processing file 15_2_s.bmp
# Processing file 16_3_s.bmp
# Processing file 20_1_s.bmp
# Processing file 19_11_s.bmp
# Processing file 8_9_s.bmp
# Processing file 18_11_s.bmp
# Successfully Created Global HSV Color Descriptors
# Testing Q=8; expects better color separation but higher compute cost
# Processing file 17_15_s.bmp
# Processing file 16_15_s.bmp
# Processing file 14_27_s.bmp
# Processing file 3_2_s.bmp
# Processing file 1_20_s.bmp
# Processing file 8_5_s.bmp
# Processing file 2_12_s.bmp
# Processing file 3_12_s.bmp
# Processing file 18_20_s.bmp
# Processing file 19_20_s.bmp
# Processing file 13_3_s.bmp
# Processing file 18_4_s.bmp
# Processing file 10_2_s.bmp
# Processing file 20_18_s.bmp
# Processing file 17_28_s.bmp
# Processing file 16_28_s.bmp
# Processing file 8_10_s.bmp
# Processing file 9_10_s.bmp
# Processing file 7_18_s.bmp
# Processing file 1_7_s.bmp
# Processing file 9_1_s.bmp
# Processing file 6_18_s.bmp
# Processing file 2_6_s.bmp
# Processing file 11_6_s.bmp
# Processing file 5_17_s.bmp
# Processing file 4_17_s.bmp
# Processing file 12_7_s.bmp
# Processing file 7_25_s.bmp
# Processing file 6_25_s.bmp
# Processing file 12_22_s.bmp
# Processing file 13_22_s.bmp
# Processing file 10_10_s.bmp
# Processing file 11_10_s.bmp
# Processing file 7_27_s.bmp
# Processing file 6_27_s.bmp
# Processing file 12_5_s.bmp
# Processing file 5_15_s.bmp
# Processing file 4_15_s.bmp
# Processing file 11_4_s.bmp
# Processing file 19_2_s.bmp
# Processing file 10_12_s.bmp
# Processing file 11_12_s.bmp
# Processing file 4_9_s.bmp
# Processing file 12_20_s.bmp
# Processing file 13_20_s.bmp
# Processing file 7_8_s.bmp
# Processing file 14_8_s.bmp
# Processing file 8_12_s.bmp
# Processing file 9_12_s.bmp
# Processing file 17_9_s.bmp
# Processing file 5_28_s.bmp
# Processing file 4_28_s.bmp
# Processing file 2_4_s.bmp
# Processing file 1_5_s.bmp
# Processing file 9_3_s.bmp
# Processing file 18_6_s.bmp
# Processing file 13_1_s.bmp
# Processing file 18_22_s.bmp
# Processing file 19_22_s.bmp
# Processing file 15_18_s.bmp
# Processing file 14_18_s.bmp
# Processing file 14_25_s.bmp
# Processing file 17_17_s.bmp
# Processing file 16_17_s.bmp
# Processing file 2_10_s.bmp
# Processing file 3_10_s.bmp
# Processing file 8_7_s.bmp
# Processing file 1_22_s.bmp
# Processing file 5_9_s.bmp
# Processing file 6_8_s.bmp
# Processing file 2_29_s.bmp
# Processing file 13_5_s.bmp
# Processing file 3_29_s.bmp
# Processing file 18_26_s.bmp
# Processing file 19_26_s.bmp
# Processing file 18_2_s.bmp
# Processing file 10_4_s.bmp
# Processing file 1_26_s.bmp
# Processing file 10_32_s.bmp
# Processing file 3_4_s.bmp
# Processing file 2_14_s.bmp
# Processing file 3_14_s.bmp
# Processing file 8_3_s.bmp
# Processing file 17_13_s.bmp
# Processing file 16_13_s.bmp
# Processing file 15_8_s.bmp
# Processing file 15_21_s.bmp
# Processing file 14_21_s.bmp
# Processing file 16_9_s.bmp
# Processing file 12_24_s.bmp
# Processing file 13_24_s.bmp
# Processing file 2_30_s.bmp
# Processing file 3_30_s.bmp
# Processing file 10_16_s.bmp
# Processing file 11_16_s.bmp
# Processing file 5_11_s.bmp
# Processing file 4_11_s.bmp
# Processing file 19_6_s.bmp
# Processing file 7_23_s.bmp
# Processing file 6_23_s.bmp
# Processing file 12_1_s.bmp
# Processing file 1_1_s.bmp
# Processing file 9_7_s.bmp
# Processing file 12_19_s.bmp
# Processing file 13_19_s.bmp
# Processing file 8_16_s.bmp
# Processing file 9_16_s.bmp
# Processing file 2_2_s.bmp
# Processing file 1_3_s.bmp
# Processing file 9_5_s.bmp
# Processing file 8_14_s.bmp
# Processing file 9_14_s.bmp
# Processing file 10_29_s.bmp
# Processing file 11_29_s.bmp
# Processing file 10_14_s.bmp
# Processing file 11_14_s.bmp
# Processing file 8_29_s.bmp
# Processing file 9_29_s.bmp
# Processing file 12_26_s.bmp
# Processing file 13_26_s.bmp
# Processing file 12_3_s.bmp
# Processing file 7_21_s.bmp
# Processing file 6_21_s.bmp
# Processing file 11_2_s.bmp
# Processing file 19_4_s.bmp
# Processing file 5_13_s.bmp
# Processing file 4_13_s.bmp
# Processing file 8_1_s.bmp
# Processing file 18_19_s.bmp
# Processing file 19_19_s.bmp
# Processing file 2_16_s.bmp
# Processing file 3_16_s.bmp
# Processing file 20_9_s.bmp
# Processing file 10_30_s.bmp
# Processing file 3_6_s.bmp
# Processing file 11_30_s.bmp
# Processing file 20_21_s.bmp
# Processing file 1_24_s.bmp
# Processing file 15_23_s.bmp
# Processing file 14_23_s.bmp
# Processing file 17_11_s.bmp
# Processing file 16_11_s.bmp
# Processing file 10_6_s.bmp
# Processing file 1_19_s.bmp
# Processing file 18_24_s.bmp
# Processing file 19_24_s.bmp
# Processing file 8_30_s.bmp
# Processing file 13_7_s.bmp
# Processing file 9_30_s.bmp
# Processing file 5_29_s.bmp
# Processing file 4_29_s.bmp
# Processing file 2_5_s.bmp
# Processing file 9_2_s.bmp
# Processing file 1_4_s.bmp
# Processing file 14_9_s.bmp
# Processing file 8_13_s.bmp
# Processing file 9_13_s.bmp
# Processing file 17_8_s.bmp
# Processing file 10_13_s.bmp
# Processing file 11_13_s.bmp
# Processing file 4_8_s.bmp
# Processing file 12_21_s.bmp
# Processing file 13_21_s.bmp
# Processing file 7_9_s.bmp
# Processing file 7_26_s.bmp
# Processing file 6_26_s.bmp
# Processing file 12_4_s.bmp
# Processing file 5_14_s.bmp
# Processing file 4_14_s.bmp
# Processing file 19_3_s.bmp
# Processing file 11_5_s.bmp
# Processing file 2_11_s.bmp
# Processing file 3_11_s.bmp
# Processing file 8_6_s.bmp
# Processing file 1_23_s.bmp
# Processing file 3_1_s.bmp
# Processing file 15_24_s.bmp
# Processing file 14_24_s.bmp
# Processing file 5_30_s.bmp
# Processing file 4_30_s.bmp
# Processing file 17_16_s.bmp
# Processing file 16_16_s.bmp
# Processing file 15_19_s.bmp
# Processing file 14_19_s.bmp
# Processing file 10_1_s.bmp
# Processing file 18_7_s.bmp
# Processing file 18_23_s.bmp
# Processing file 19_23_s.bmp
# Processing file 17_29_s.bmp
# Processing file 16_29_s.bmp
# Processing file 18_21_s.bmp
# Processing file 19_21_s.bmp
# Processing file 13_2_s.bmp
# Processing file 10_3_s.bmp
# Processing file 18_5_s.bmp
# Processing file 20_19_s.bmp
# Processing file 3_3_s.bmp
# Processing file 1_21_s.bmp
# Processing file 8_4_s.bmp
# Processing file 2_13_s.bmp
# Processing file 3_13_s.bmp
# Processing file 17_14_s.bmp
# Processing file 16_14_s.bmp
# Processing file 14_26_s.bmp
# Processing file 12_23_s.bmp
# Processing file 13_23_s.bmp
# Processing file 10_11_s.bmp
# Processing file 11_11_s.bmp
# Processing file 19_1_s.bmp
# Processing file 11_7_s.bmp
# Processing file 5_16_s.bmp
# Processing file 4_16_s.bmp
# Processing file 17_30_s.bmp
# Processing file 16_30_s.bmp
# Processing file 12_6_s.bmp
# Processing file 7_24_s.bmp
# Processing file 6_24_s.bmp
# Processing file 7_19_s.bmp
# Processing file 6_19_s.bmp
# Processing file 1_6_s.bmp
# Processing file 2_7_s.bmp
# Processing file 8_11_s.bmp
# Processing file 9_11_s.bmp
# Processing file 12_2_s.bmp
# Processing file 7_20_s.bmp
# Processing file 6_20_s.bmp
# Processing file 19_5_s.bmp
# Processing file 11_3_s.bmp
# Processing file 5_12_s.bmp
# Processing file 4_12_s.bmp
# Processing file 10_15_s.bmp
# Processing file 11_15_s.bmp
# Processing file 8_28_s.bmp
# Processing file 9_28_s.bmp
# Processing file 12_27_s.bmp
# Processing file 13_27_s.bmp
# Processing file 8_15_s.bmp
# Processing file 9_15_s.bmp
# Processing file 10_28_s.bmp
# Processing file 11_28_s.bmp
# Processing file 2_3_s.bmp
# Processing file 9_4_s.bmp
# Processing file 1_2_s.bmp
# Processing file 10_7_s.bmp
# Processing file 18_1_s.bmp
# Processing file 1_18_s.bmp
# Processing file 18_25_s.bmp
# Processing file 19_25_s.bmp
# Processing file 13_6_s.bmp
# Processing file 15_22_s.bmp
# Processing file 14_22_s.bmp
# Processing file 17_10_s.bmp
# Processing file 16_10_s.bmp
# Processing file 18_18_s.bmp
# Processing file 19_18_s.bmp
# Processing file 2_17_s.bmp
# Processing file 20_8_s.bmp
# Processing file 3_17_s.bmp
# Processing file 10_31_s.bmp
# Processing file 3_7_s.bmp
# Processing file 1_25_s.bmp
# Processing file 20_20_s.bmp
# Processing file 17_12_s.bmp
# Processing file 16_12_s.bmp
# Processing file 15_9_s.bmp
# Processing file 15_20_s.bmp
# Processing file 14_20_s.bmp
# Processing file 16_8_s.bmp
# Processing file 1_27_s.bmp
# Processing file 3_5_s.bmp
# Processing file 2_15_s.bmp
# Processing file 3_15_s.bmp
# Processing file 8_2_s.bmp
# Processing file 2_28_s.bmp
# Processing file 13_4_s.bmp
# Processing file 3_28_s.bmp
# Processing file 18_27_s.bmp
# Processing file 19_27_s.bmp
# Processing file 10_5_s.bmp
# Processing file 18_3_s.bmp
# Processing file 5_8_s.bmp
# Processing file 6_9_s.bmp
# Processing file 12_18_s.bmp
# Processing file 13_18_s.bmp
# Processing file 8_17_s.bmp
# Processing file 9_17_s.bmp
# Processing file 9_6_s.bmp
# Processing file 2_1_s.bmp
# Processing file 5_10_s.bmp
# Processing file 4_10_s.bmp
# Processing file 19_7_s.bmp
# Processing file 11_1_s.bmp
# Processing file 7_22_s.bmp
# Processing file 6_22_s.bmp
# Processing file 12_25_s.bmp
# Processing file 13_25_s.bmp
# Processing file 10_17_s.bmp
# Processing file 11_17_s.bmp
# Processing file 9_26_s.bmp
# Processing file 7_1_s.bmp
# Processing file 8_26_s.bmp
# Processing file 13_29_s.bmp
# Processing file 12_29_s.bmp
# Processing file 11_26_s.bmp
# Processing file 10_26_s.bmp
# Processing file 13_14_s.bmp
# Processing file 14_1_s.bmp
# Processing file 12_14_s.bmp
# Processing file 6_13_s.bmp
# Processing file 7_13_s.bmp
# Processing file 4_21_s.bmp
# Processing file 5_21_s.bmp
# Processing file 13_30_s.bmp
# Processing file 12_30_s.bmp
# Processing file 3_24_s.bmp
# Processing file 13_8_s.bmp
# Processing file 2_24_s.bmp
# Processing file 20_13_s.bmp
# Processing file 1_16_s.bmp
# Processing file 10_9_s.bmp
# Processing file 14_11_s.bmp
# Processing file 5_4_s.bmp
# Processing file 15_11_s.bmp
# Processing file 16_23_s.bmp
# Processing file 6_5_s.bmp
# Processing file 17_23_s.bmp
# Processing file 15_5_s.bmp
# Processing file 16_4_s.bmp
# Processing file 3_9_s.bmp
# Processing file 19_16_s.bmp
# Processing file 18_16_s.bmp
# Processing file 20_6_s.bmp
# Processing file 3_19_s.bmp
# Processing file 2_19_s.bmp
# Processing file 16_6_s.bmp
# Processing file 15_7_s.bmp
# Processing file 20_4_s.bmp
# Processing file 19_14_s.bmp
# Processing file 18_14_s.bmp
# Processing file 1_29_s.bmp
# Processing file 20_11_s.bmp
# Processing file 1_14_s.bmp
# Processing file 3_26_s.bmp
# Processing file 2_26_s.bmp
# Processing file 19_29_s.bmp
# Processing file 12_32_s.bmp
# Processing file 18_29_s.bmp
# Processing file 16_21_s.bmp
# Processing file 6_7_s.bmp
# Processing file 17_21_s.bmp
# Processing file 14_13_s.bmp
# Processing file 5_6_s.bmp
# Processing file 15_13_s.bmp
# Processing file 13_16_s.bmp
# Processing file 14_3_s.bmp
# Processing file 12_16_s.bmp
# Processing file 9_19_s.bmp
# Processing file 8_19_s.bmp
# Processing file 17_2_s.bmp
# Processing file 11_24_s.bmp
# Processing file 10_24_s.bmp
# Processing file 1_30_s.bmp
# Processing file 4_23_s.bmp
# Processing file 5_23_s.bmp
# Processing file 6_11_s.bmp
# Processing file 9_8_s.bmp
# Processing file 7_11_s.bmp
# Processing file 19_9_s.bmp
# Processing file 11_19_s.bmp
# Processing file 10_19_s.bmp
# Processing file 4_2_s.bmp
# Processing file 19_30_s.bmp
# Processing file 18_30_s.bmp
# Processing file 9_24_s.bmp
# Processing file 7_3_s.bmp
# Processing file 8_24_s.bmp
# Processing file 6_15_s.bmp
# Processing file 7_15_s.bmp
# Processing file 4_27_s.bmp
# Processing file 5_27_s.bmp
# Processing file 17_6_s.bmp
# Processing file 11_20_s.bmp
# Processing file 10_20_s.bmp
# Processing file 13_12_s.bmp
# Processing file 14_7_s.bmp
# Processing file 12_12_s.bmp
# Processing file 9_20_s.bmp
# Processing file 7_7_s.bmp
# Processing file 8_20_s.bmp
# Processing file 4_6_s.bmp
# Processing file 6_28_s.bmp
# Processing file 7_28_s.bmp
# Processing file 19_10_s.bmp
# Processing file 18_10_s.bmp
# Processing file 8_8_s.bmp
# Processing file 16_18_s.bmp
# Processing file 17_18_s.bmp
# Processing file 15_3_s.bmp
# Processing file 16_2_s.bmp
# Processing file 14_17_s.bmp
# Processing file 5_2_s.bmp
# Processing file 15_17_s.bmp
# Processing file 16_25_s.bmp
# Processing file 6_3_s.bmp
# Processing file 17_25_s.bmp
# Processing file 3_22_s.bmp
# Processing file 2_22_s.bmp
# Processing file 20_15_s.bmp
# Processing file 1_10_s.bmp
# Processing file 18_9_s.bmp
# Processing file 16_27_s.bmp
# Processing file 6_1_s.bmp
# Processing file 17_27_s.bmp
# Processing file 14_15_s.bmp
# Processing file 15_15_s.bmp
# Processing file 20_17_s.bmp
# Processing file 1_12_s.bmp
# Processing file 12_34_s.bmp
# Processing file 3_20_s.bmp
# Processing file 2_20_s.bmp
# Processing file 19_12_s.bmp
# Processing file 18_12_s.bmp
# Processing file 20_2_s.bmp
# Processing file 14_28_s.bmp
# Processing file 15_1_s.bmp
# Processing file 4_4_s.bmp
# Processing file 9_22_s.bmp
# Processing file 7_5_s.bmp
# Processing file 8_22_s.bmp
# Processing file 12_8_s.bmp
# Processing file 11_9_s.bmp
# Processing file 4_18_s.bmp
# Processing file 5_18_s.bmp
# Processing file 2_9_s.bmp
# Processing file 4_25_s.bmp
# Processing file 5_25_s.bmp
# Processing file 6_17_s.bmp
# Processing file 1_8_s.bmp
# Processing file 7_17_s.bmp
# Processing file 13_10_s.bmp
# Processing file 14_5_s.bmp
# Processing file 12_10_s.bmp
# Processing file 17_4_s.bmp
# Processing file 11_22_s.bmp
# Processing file 10_22_s.bmp
# Processing file 16_20_s.bmp
# Processing file 6_6_s.bmp
# Processing file 17_20_s.bmp
# Processing file 14_12_s.bmp
# Processing file 15_12_s.bmp
# Processing file 5_7_s.bmp
# Processing file 1_15_s.bmp
# Processing file 20_10_s.bmp
# Processing file 3_27_s.bmp
# Processing file 2_27_s.bmp
# Processing file 19_28_s.bmp
# Processing file 18_28_s.bmp
# Processing file 12_33_s.bmp
# Processing file 20_5_s.bmp
# Processing file 19_15_s.bmp
# Processing file 18_15_s.bmp
# Processing file 1_28_s.bmp
# Processing file 16_7_s.bmp
# Processing file 15_6_s.bmp
# Processing file 11_18_s.bmp
# Processing file 10_18_s.bmp
# Processing file 4_3_s.bmp
# Processing file 7_2_s.bmp
# Processing file 9_25_s.bmp
# Processing file 8_25_s.bmp
# Processing file 19_8_s.bmp
# Processing file 4_22_s.bmp
# Processing file 5_22_s.bmp
# Processing file 6_10_s.bmp
# Processing file 9_9_s.bmp
# Processing file 7_10_s.bmp
# Processing file 14_2_s.bmp
# Processing file 13_17_s.bmp
# Processing file 12_17_s.bmp
# Processing file 9_18_s.bmp
# Processing file 8_18_s.bmp
# Processing file 17_3_s.bmp
# Processing file 11_25_s.bmp
# Processing file 10_25_s.bmp
# Processing file 6_12_s.bmp
# Processing file 7_12_s.bmp
# Processing file 4_20_s.bmp
# Processing file 5_20_s.bmp
# Processing file 17_1_s.bmp
# Processing file 11_27_s.bmp
# Processing file 10_27_s.bmp
# Processing file 13_15_s.bmp
# Processing file 12_15_s.bmp
# Processing file 9_27_s.bmp
# Processing file 8_27_s.bmp
# Processing file 13_28_s.bmp
# Processing file 12_28_s.bmp
# Processing file 4_1_s.bmp
# Processing file 3_8_s.bmp
# Processing file 19_17_s.bmp
# Processing file 18_17_s.bmp
# Processing file 3_18_s.bmp
# Processing file 20_7_s.bmp
# Processing file 2_18_s.bmp
# Processing file 15_4_s.bmp
# Processing file 16_5_s.bmp
# Processing file 14_10_s.bmp
# Processing file 15_10_s.bmp
# Processing file 5_5_s.bmp
# Processing file 16_22_s.bmp
# Processing file 6_4_s.bmp
# Processing file 17_22_s.bmp
# Processing file 12_31_s.bmp
# Processing file 3_25_s.bmp
# Processing file 13_9_s.bmp
# Processing file 2_25_s.bmp
# Processing file 1_17_s.bmp
# Processing file 20_12_s.bmp
# Processing file 10_8_s.bmp
# Processing file 16_1_s.bmp
# Processing file 14_29_s.bmp
# Processing file 19_13_s.bmp
# Processing file 18_13_s.bmp
# Processing file 20_3_s.bmp
# Processing file 1_13_s.bmp
# Processing file 20_16_s.bmp
# Processing file 3_21_s.bmp
# Processing file 2_21_s.bmp
# Processing file 16_26_s.bmp
# Processing file 17_26_s.bmp
# Processing file 14_14_s.bmp
# Processing file 15_14_s.bmp
# Processing file 5_1_s.bmp
# Processing file 14_4_s.bmp
# Processing file 13_11_s.bmp
# Processing file 12_11_s.bmp
# Processing file 17_5_s.bmp
# Processing file 11_23_s.bmp
# Processing file 10_23_s.bmp
# Processing file 14_30_s.bmp
# Processing file 2_8_s.bmp
# Processing file 4_24_s.bmp
# Processing file 5_24_s.bmp
# Processing file 1_9_s.bmp
# Processing file 6_16_s.bmp
# Processing file 7_16_s.bmp
# Processing file 12_9_s.bmp
# Processing file 11_8_s.bmp
# Processing file 4_19_s.bmp
# Processing file 5_19_s.bmp
# Processing file 4_5_s.bmp
# Processing file 7_4_s.bmp
# Processing file 9_23_s.bmp
# Processing file 8_23_s.bmp
# Processing file 6_29_s.bmp
# Processing file 7_29_s.bmp
# Processing file 7_6_s.bmp
# Processing file 9_21_s.bmp
# Processing file 8_21_s.bmp
# Processing file 4_7_s.bmp
# Processing file 17_7_s.bmp
# Processing file 11_21_s.bmp
# Processing file 10_21_s.bmp
# Processing file 14_6_s.bmp
# Processing file 13_13_s.bmp
# Processing file 12_13_s.bmp
# Processing file 6_14_s.bmp
# Processing file 7_14_s.bmp
# Processing file 4_26_s.bmp
# Processing file 5_26_s.bmp
# Processing file 3_23_s.bmp
# Processing file 2_23_s.bmp
# Processing file 1_11_s.bmp
# Processing file 20_14_s.bmp
# Processing file 18_8_s.bmp
# Processing file 14_16_s.bmp
# Processing file 15_16_s.bmp
# Processing file 5_3_s.bmp
# Processing file 16_24_s.bmp
# Processing file 6_2_s.bmp
# Processing file 17_24_s.bmp
# Processing file 6_30_s.bmp
# Processing file 7_30_s.bmp
# Processing file 16_19_s.bmp
# Processing file 17_19_s.bmp
# Processing file 15_2_s.bmp
# Processing file 16_3_s.bmp
# Processing file 20_1_s.bmp
# Processing file 19_11_s.bmp
# Processing file 8_9_s.bmp
# Processing file 18_11_s.bmp
# Successfully Created Global HSV Color Descriptors
# Testing Q=16; expects better color separation but higher compute cost
# Processing file 17_15_s.bmp
# Processing file 16_15_s.bmp
# Processing file 14_27_s.bmp
# Processing file 3_2_s.bmp
# Processing file 1_20_s.bmp
# Processing file 8_5_s.bmp
# Processing file 2_12_s.bmp
# Processing file 3_12_s.bmp
# Processing file 18_20_s.bmp
# Processing file 19_20_s.bmp
# Processing file 13_3_s.bmp
# Processing file 18_4_s.bmp
# Processing file 10_2_s.bmp
# Processing file 20_18_s.bmp
# Processing file 17_28_s.bmp
# Processing file 16_28_s.bmp
# Processing file 8_10_s.bmp
# Processing file 9_10_s.bmp
# Processing file 7_18_s.bmp
# Processing file 1_7_s.bmp
# Processing file 9_1_s.bmp
# Processing file 6_18_s.bmp
# Processing file 2_6_s.bmp
# Processing file 11_6_s.bmp
# Processing file 5_17_s.bmp
# Processing file 4_17_s.bmp
# Processing file 12_7_s.bmp
# Processing file 7_25_s.bmp
# Processing file 6_25_s.bmp
# Processing file 12_22_s.bmp
# Processing file 13_22_s.bmp
# Processing file 10_10_s.bmp
# Processing file 11_10_s.bmp
# Processing file 7_27_s.bmp
# Processing file 6_27_s.bmp
# Processing file 12_5_s.bmp
# Processing file 5_15_s.bmp
# Processing file 4_15_s.bmp
# Processing file 11_4_s.bmp
# Processing file 19_2_s.bmp
# Processing file 10_12_s.bmp
# Processing file 11_12_s.bmp
# Processing file 4_9_s.bmp
# Processing file 12_20_s.bmp
# Processing file 13_20_s.bmp
# Processing file 7_8_s.bmp
# Processing file 14_8_s.bmp
# Processing file 8_12_s.bmp
# Processing file 9_12_s.bmp
# Processing file 17_9_s.bmp
# Processing file 5_28_s.bmp
# Processing file 4_28_s.bmp
# Processing file 2_4_s.bmp
# Processing file 1_5_s.bmp
# Processing file 9_3_s.bmp
# Processing file 18_6_s.bmp
# Processing file 13_1_s.bmp
# Processing file 18_22_s.bmp
# Processing file 19_22_s.bmp
# Processing file 15_18_s.bmp
# Processing file 14_18_s.bmp
# Processing file 14_25_s.bmp
# Processing file 17_17_s.bmp
# Processing file 16_17_s.bmp
# Processing file 2_10_s.bmp
# Processing file 3_10_s.bmp
# Processing file 8_7_s.bmp
# Processing file 1_22_s.bmp
# Processing file 5_9_s.bmp
# Processing file 6_8_s.bmp
# Processing file 2_29_s.bmp
# Processing file 13_5_s.bmp
# Processing file 3_29_s.bmp
# Processing file 18_26_s.bmp
# Processing file 19_26_s.bmp
# Processing file 18_2_s.bmp
# Processing file 10_4_s.bmp
# Processing file 1_26_s.bmp
# Processing file 10_32_s.bmp
# Processing file 3_4_s.bmp
# Processing file 2_14_s.bmp
# Processing file 3_14_s.bmp
# Processing file 8_3_s.bmp
# Processing file 17_13_s.bmp
# Processing file 16_13_s.bmp
# Processing file 15_8_s.bmp
# Processing file 15_21_s.bmp
# Processing file 14_21_s.bmp
# Processing file 16_9_s.bmp
# Processing file 12_24_s.bmp
# Processing file 13_24_s.bmp
# Processing file 2_30_s.bmp
# Processing file 3_30_s.bmp
# Processing file 10_16_s.bmp
# Processing file 11_16_s.bmp
# Processing file 5_11_s.bmp
# Processing file 4_11_s.bmp
# Processing file 19_6_s.bmp
# Processing file 7_23_s.bmp
# Processing file 6_23_s.bmp
# Processing file 12_1_s.bmp
# Processing file 1_1_s.bmp
# Processing file 9_7_s.bmp
# Processing file 12_19_s.bmp
# Processing file 13_19_s.bmp
# Processing file 8_16_s.bmp
# Processing file 9_16_s.bmp
# Processing file 2_2_s.bmp
# Processing file 1_3_s.bmp
# Processing file 9_5_s.bmp
# Processing file 8_14_s.bmp
# Processing file 9_14_s.bmp
# Processing file 10_29_s.bmp
# Processing file 11_29_s.bmp
# Processing file 10_14_s.bmp
# Processing file 11_14_s.bmp
# Processing file 8_29_s.bmp
# Processing file 9_29_s.bmp
# Processing file 12_26_s.bmp
# Processing file 13_26_s.bmp
# Processing file 12_3_s.bmp
# Processing file 7_21_s.bmp
# Processing file 6_21_s.bmp
# Processing file 11_2_s.bmp
# Processing file 19_4_s.bmp
# Processing file 5_13_s.bmp
# Processing file 4_13_s.bmp
# Processing file 8_1_s.bmp
# Processing file 18_19_s.bmp
# Processing file 19_19_s.bmp
# Processing file 2_16_s.bmp
# Processing file 3_16_s.bmp
# Processing file 20_9_s.bmp
# Processing file 10_30_s.bmp
# Processing file 3_6_s.bmp
# Processing file 11_30_s.bmp
# Processing file 20_21_s.bmp
# Processing file 1_24_s.bmp
# Processing file 15_23_s.bmp
# Processing file 14_23_s.bmp
# Processing file 17_11_s.bmp
# Processing file 16_11_s.bmp
# Processing file 10_6_s.bmp
# Processing file 1_19_s.bmp
# Processing file 18_24_s.bmp
# Processing file 19_24_s.bmp
# Processing file 8_30_s.bmp
# Processing file 13_7_s.bmp
# Processing file 9_30_s.bmp
# Processing file 5_29_s.bmp
# Processing file 4_29_s.bmp
# Processing file 2_5_s.bmp
# Processing file 9_2_s.bmp
# Processing file 1_4_s.bmp
# Processing file 14_9_s.bmp
# Processing file 8_13_s.bmp
# Processing file 9_13_s.bmp
# Processing file 17_8_s.bmp
# Processing file 10_13_s.bmp
# Processing file 11_13_s.bmp
# Processing file 4_8_s.bmp
# Processing file 12_21_s.bmp
# Processing file 13_21_s.bmp
# Processing file 7_9_s.bmp
# Processing file 7_26_s.bmp
# Processing file 6_26_s.bmp
# Processing file 12_4_s.bmp
# Processing file 5_14_s.bmp
# Processing file 4_14_s.bmp
# Processing file 19_3_s.bmp
# Processing file 11_5_s.bmp
# Processing file 2_11_s.bmp
# Processing file 3_11_s.bmp
# Processing file 8_6_s.bmp
# Processing file 1_23_s.bmp
# Processing file 3_1_s.bmp
# Processing file 15_24_s.bmp
# Processing file 14_24_s.bmp
# Processing file 5_30_s.bmp
# Processing file 4_30_s.bmp
# Processing file 17_16_s.bmp
# Processing file 16_16_s.bmp
# Processing file 15_19_s.bmp
# Processing file 14_19_s.bmp
# Processing file 10_1_s.bmp
# Processing file 18_7_s.bmp
# Processing file 18_23_s.bmp
# Processing file 19_23_s.bmp
# Processing file 17_29_s.bmp
# Processing file 16_29_s.bmp
# Processing file 18_21_s.bmp
# Processing file 19_21_s.bmp
# Processing file 13_2_s.bmp
# Processing file 10_3_s.bmp
# Processing file 18_5_s.bmp
# Processing file 20_19_s.bmp
# Processing file 3_3_s.bmp
# Processing file 1_21_s.bmp
# Processing file 8_4_s.bmp
# Processing file 2_13_s.bmp
# Processing file 3_13_s.bmp
# Processing file 17_14_s.bmp
# Processing file 16_14_s.bmp
# Processing file 14_26_s.bmp
# Processing file 12_23_s.bmp
# Processing file 13_23_s.bmp
# Processing file 10_11_s.bmp
# Processing file 11_11_s.bmp
# Processing file 19_1_s.bmp
# Processing file 11_7_s.bmp
# Processing file 5_16_s.bmp
# Processing file 4_16_s.bmp
# Processing file 17_30_s.bmp
# Processing file 16_30_s.bmp
# Processing file 12_6_s.bmp
# Processing file 7_24_s.bmp
# Processing file 6_24_s.bmp
# Processing file 7_19_s.bmp
# Processing file 6_19_s.bmp
# Processing file 1_6_s.bmp
# Processing file 2_7_s.bmp
# Processing file 8_11_s.bmp
# Processing file 9_11_s.bmp
# Processing file 12_2_s.bmp
# Processing file 7_20_s.bmp
# Processing file 6_20_s.bmp
# Processing file 19_5_s.bmp
# Processing file 11_3_s.bmp
# Processing file 5_12_s.bmp
# Processing file 4_12_s.bmp
# Processing file 10_15_s.bmp
# Processing file 11_15_s.bmp
# Processing file 8_28_s.bmp
# Processing file 9_28_s.bmp
# Processing file 12_27_s.bmp
# Processing file 13_27_s.bmp
# Processing file 8_15_s.bmp
# Processing file 9_15_s.bmp
# Processing file 10_28_s.bmp
# Processing file 11_28_s.bmp
# Processing file 2_3_s.bmp
# Processing file 9_4_s.bmp
# Processing file 1_2_s.bmp
# Processing file 10_7_s.bmp
# Processing file 18_1_s.bmp
# Processing file 1_18_s.bmp
# Processing file 18_25_s.bmp
# Processing file 19_25_s.bmp
# Processing file 13_6_s.bmp
# Processing file 15_22_s.bmp
# Processing file 14_22_s.bmp
# Processing file 17_10_s.bmp
# Processing file 16_10_s.bmp
# Processing file 18_18_s.bmp
# Processing file 19_18_s.bmp
# Processing file 2_17_s.bmp
# Processing file 20_8_s.bmp
# Processing file 3_17_s.bmp
# Processing file 10_31_s.bmp
# Processing file 3_7_s.bmp
# Processing file 1_25_s.bmp
# Processing file 20_20_s.bmp
# Processing file 17_12_s.bmp
# Processing file 16_12_s.bmp
# Processing file 15_9_s.bmp
# Processing file 15_20_s.bmp
# Processing file 14_20_s.bmp
# Processing file 16_8_s.bmp
# Processing file 1_27_s.bmp
# Processing file 3_5_s.bmp
# Processing file 2_15_s.bmp
# Processing file 3_15_s.bmp
# Processing file 8_2_s.bmp
# Processing file 2_28_s.bmp
# Processing file 13_4_s.bmp
# Processing file 3_28_s.bmp
# Processing file 18_27_s.bmp
# Processing file 19_27_s.bmp
# Processing file 10_5_s.bmp
# Processing file 18_3_s.bmp
# Processing file 5_8_s.bmp
# Processing file 6_9_s.bmp
# Processing file 12_18_s.bmp
# Processing file 13_18_s.bmp
# Processing file 8_17_s.bmp
# Processing file 9_17_s.bmp
# Processing file 9_6_s.bmp
# Processing file 2_1_s.bmp
# Processing file 5_10_s.bmp
# Processing file 4_10_s.bmp
# Processing file 19_7_s.bmp
# Processing file 11_1_s.bmp
# Processing file 7_22_s.bmp
# Processing file 6_22_s.bmp
# Processing file 12_25_s.bmp
# Processing file 13_25_s.bmp
# Processing file 10_17_s.bmp
# Processing file 11_17_s.bmp
# Processing file 9_26_s.bmp
# Processing file 7_1_s.bmp
# Processing file 8_26_s.bmp
# Processing file 13_29_s.bmp
# Processing file 12_29_s.bmp
# Processing file 11_26_s.bmp
# Processing file 10_26_s.bmp
# Processing file 13_14_s.bmp
# Processing file 14_1_s.bmp
# Processing file 12_14_s.bmp
# Processing file 6_13_s.bmp
# Processing file 7_13_s.bmp
# Processing file 4_21_s.bmp
# Processing file 5_21_s.bmp
# Processing file 13_30_s.bmp
# Processing file 12_30_s.bmp
# Processing file 3_24_s.bmp
# Processing file 13_8_s.bmp
# Processing file 2_24_s.bmp
# Processing file 20_13_s.bmp
# Processing file 1_16_s.bmp
# Processing file 10_9_s.bmp
# Processing file 14_11_s.bmp
# Processing file 5_4_s.bmp
# Processing file 15_11_s.bmp
# Processing file 16_23_s.bmp
# Processing file 6_5_s.bmp
# Processing file 17_23_s.bmp
# Processing file 15_5_s.bmp
# Processing file 16_4_s.bmp
# Processing file 3_9_s.bmp
# Processing file 19_16_s.bmp
# Processing file 18_16_s.bmp
# Processing file 20_6_s.bmp
# Processing file 3_19_s.bmp
# Processing file 2_19_s.bmp
# Processing file 16_6_s.bmp
# Processing file 15_7_s.bmp
# Processing file 20_4_s.bmp
# Processing file 19_14_s.bmp
# Processing file 18_14_s.bmp
# Processing file 1_29_s.bmp
# Processing file 20_11_s.bmp
# Processing file 1_14_s.bmp
# Processing file 3_26_s.bmp
# Processing file 2_26_s.bmp
# Processing file 19_29_s.bmp
# Processing file 12_32_s.bmp
# Processing file 18_29_s.bmp
# Processing file 16_21_s.bmp
# Processing file 6_7_s.bmp
# Processing file 17_21_s.bmp
# Processing file 14_13_s.bmp
# Processing file 5_6_s.bmp
# Processing file 15_13_s.bmp
# Processing file 13_16_s.bmp
# Processing file 14_3_s.bmp
# Processing file 12_16_s.bmp
# Processing file 9_19_s.bmp
# Processing file 8_19_s.bmp
# Processing file 17_2_s.bmp
# Processing file 11_24_s.bmp
# Processing file 10_24_s.bmp
# Processing file 1_30_s.bmp
# Processing file 4_23_s.bmp
# Processing file 5_23_s.bmp
# Processing file 6_11_s.bmp
# Processing file 9_8_s.bmp
# Processing file 7_11_s.bmp
# Processing file 19_9_s.bmp
# Processing file 11_19_s.bmp
# Processing file 10_19_s.bmp
# Processing file 4_2_s.bmp
# Processing file 19_30_s.bmp
# Processing file 18_30_s.bmp
# Processing file 9_24_s.bmp
# Processing file 7_3_s.bmp
# Processing file 8_24_s.bmp
# Processing file 6_15_s.bmp
# Processing file 7_15_s.bmp
# Processing file 4_27_s.bmp
# Processing file 5_27_s.bmp
# Processing file 17_6_s.bmp
# Processing file 11_20_s.bmp
# Processing file 10_20_s.bmp
# Processing file 13_12_s.bmp
# Processing file 14_7_s.bmp
# Processing file 12_12_s.bmp
# Processing file 9_20_s.bmp
# Processing file 7_7_s.bmp
# Processing file 8_20_s.bmp
# Processing file 4_6_s.bmp
# Processing file 6_28_s.bmp
# Processing file 7_28_s.bmp
# Processing file 19_10_s.bmp
# Processing file 18_10_s.bmp
# Processing file 8_8_s.bmp
# Processing file 16_18_s.bmp
# Processing file 17_18_s.bmp
# Processing file 15_3_s.bmp
# Processing file 16_2_s.bmp
# Processing file 14_17_s.bmp
# Processing file 5_2_s.bmp
# Processing file 15_17_s.bmp
# Processing file 16_25_s.bmp
# Processing file 6_3_s.bmp
# Processing file 17_25_s.bmp
# Processing file 3_22_s.bmp
# Processing file 2_22_s.bmp
# Processing file 20_15_s.bmp
# Processing file 1_10_s.bmp
# Processing file 18_9_s.bmp
# Processing file 16_27_s.bmp
# Processing file 6_1_s.bmp
# Processing file 17_27_s.bmp
# Processing file 14_15_s.bmp
# Processing file 15_15_s.bmp
# Processing file 20_17_s.bmp
# Processing file 1_12_s.bmp
# Processing file 12_34_s.bmp
# Processing file 3_20_s.bmp
# Processing file 2_20_s.bmp
# Processing file 19_12_s.bmp
# Processing file 18_12_s.bmp
# Processing file 20_2_s.bmp
# Processing file 14_28_s.bmp
# Processing file 15_1_s.bmp
# Processing file 4_4_s.bmp
# Processing file 9_22_s.bmp
# Processing file 7_5_s.bmp
# Processing file 8_22_s.bmp
# Processing file 12_8_s.bmp
# Processing file 11_9_s.bmp
# Processing file 4_18_s.bmp
# Processing file 5_18_s.bmp
# Processing file 2_9_s.bmp
# Processing file 4_25_s.bmp
# Processing file 5_25_s.bmp
# Processing file 6_17_s.bmp
# Processing file 1_8_s.bmp
# Processing file 7_17_s.bmp
# Processing file 13_10_s.bmp
# Processing file 14_5_s.bmp
# Processing file 12_10_s.bmp
# Processing file 17_4_s.bmp
# Processing file 11_22_s.bmp
# Processing file 10_22_s.bmp
# Processing file 16_20_s.bmp
# Processing file 6_6_s.bmp
# Processing file 17_20_s.bmp
# Processing file 14_12_s.bmp
# Processing file 15_12_s.bmp
# Processing file 5_7_s.bmp
# Processing file 1_15_s.bmp
# Processing file 20_10_s.bmp
# Processing file 3_27_s.bmp
# Processing file 2_27_s.bmp
# Processing file 19_28_s.bmp
# Processing file 18_28_s.bmp
# Processing file 12_33_s.bmp
# Processing file 20_5_s.bmp
# Processing file 19_15_s.bmp
# Processing file 18_15_s.bmp
# Processing file 1_28_s.bmp
# Processing file 16_7_s.bmp
# Processing file 15_6_s.bmp
# Processing file 11_18_s.bmp
# Processing file 10_18_s.bmp
# Processing file 4_3_s.bmp
# Processing file 7_2_s.bmp
# Processing file 9_25_s.bmp
# Processing file 8_25_s.bmp
# Processing file 19_8_s.bmp
# Processing file 4_22_s.bmp
# Processing file 5_22_s.bmp
# Processing file 6_10_s.bmp
# Processing file 9_9_s.bmp
# Processing file 7_10_s.bmp
# Processing file 14_2_s.bmp
# Processing file 13_17_s.bmp
# Processing file 12_17_s.bmp
# Processing file 9_18_s.bmp
# Processing file 8_18_s.bmp
# Processing file 17_3_s.bmp
# Processing file 11_25_s.bmp
# Processing file 10_25_s.bmp
# Processing file 6_12_s.bmp
# Processing file 7_12_s.bmp
# Processing file 4_20_s.bmp
# Processing file 5_20_s.bmp
# Processing file 17_1_s.bmp
# Processing file 11_27_s.bmp
# Processing file 10_27_s.bmp
# Processing file 13_15_s.bmp
# Processing file 12_15_s.bmp
# Processing file 9_27_s.bmp
# Processing file 8_27_s.bmp
# Processing file 13_28_s.bmp
# Processing file 12_28_s.bmp
# Processing file 4_1_s.bmp
# Processing file 3_8_s.bmp
# Processing file 19_17_s.bmp
# Processing file 18_17_s.bmp
# Processing file 3_18_s.bmp
# Processing file 20_7_s.bmp
# Processing file 2_18_s.bmp
# Processing file 15_4_s.bmp
# Processing file 16_5_s.bmp
# Processing file 14_10_s.bmp
# Processing file 15_10_s.bmp
# Processing file 5_5_s.bmp
# Processing file 16_22_s.bmp
# Processing file 6_4_s.bmp
# Processing file 17_22_s.bmp
# Processing file 12_31_s.bmp
# Processing file 3_25_s.bmp
# Processing file 13_9_s.bmp
# Processing file 2_25_s.bmp
# Processing file 1_17_s.bmp
# Processing file 20_12_s.bmp
# Processing file 10_8_s.bmp
# Processing file 16_1_s.bmp
# Processing file 14_29_s.bmp
# Processing file 19_13_s.bmp
# Processing file 18_13_s.bmp
# Processing file 20_3_s.bmp
# Processing file 1_13_s.bmp
# Processing file 20_16_s.bmp
# Processing file 3_21_s.bmp
# Processing file 2_21_s.bmp
# Processing file 16_26_s.bmp
# Processing file 17_26_s.bmp
# Processing file 14_14_s.bmp
# Processing file 15_14_s.bmp
# Processing file 5_1_s.bmp
# Processing file 14_4_s.bmp
# Processing file 13_11_s.bmp
# Processing file 12_11_s.bmp
# Processing file 17_5_s.bmp
# Processing file 11_23_s.bmp
# Processing file 10_23_s.bmp
# Processing file 14_30_s.bmp
# Processing file 2_8_s.bmp
# Processing file 4_24_s.bmp
# Processing file 5_24_s.bmp
# Processing file 1_9_s.bmp
# Processing file 6_16_s.bmp
# Processing file 7_16_s.bmp
# Processing file 12_9_s.bmp
# Processing file 11_8_s.bmp
# Processing file 4_19_s.bmp
# Processing file 5_19_s.bmp
# Processing file 4_5_s.bmp
# Processing file 7_4_s.bmp
# Processing file 9_23_s.bmp
# Processing file 8_23_s.bmp
# Processing file 6_29_s.bmp
# Processing file 7_29_s.bmp
# Processing file 7_6_s.bmp
# Processing file 9_21_s.bmp
# Processing file 8_21_s.bmp
# Processing file 4_7_s.bmp
# Processing file 17_7_s.bmp
# Processing file 11_21_s.bmp
# Processing file 10_21_s.bmp
# Processing file 14_6_s.bmp
# Processing file 13_13_s.bmp
# Processing file 12_13_s.bmp
# Processing file 6_14_s.bmp
# Processing file 7_14_s.bmp
# ...
# Processing file 2_12_s.bmp
# Processing file 3_12_s.bmp
# Processing file 18_20_s.bmp
# Processing file 19_20_s.bmp
# Processing file 13_3_s.bmp
# Processing file 18_4_s.bmp
# Processing file 10_2_s.bmp
# Processing file 20_18_s.bmp
# Processing file 17_28_s.bmp
# Processing file 16_28_s.bmp
# Processing file 8_10_s.bmp
# Processing file 9_10_s.bmp
# Processing file 7_18_s.bmp
# Processing file 1_7_s.bmp
# Processing file 9_1_s.bmp
# Processing file 6_18_s.bmp
# Processing file 2_6_s.bmp
# Processing file 11_6_s.bmp
# Processing file 5_17_s.bmp
# Processing file 4_17_s.bmp
# Processing file 12_7_s.bmp
# Processing file 7_25_s.bmp
# Processing file 6_25_s.bmp
# Processing file 12_22_s.bmp
# Processing file 13_22_s.bmp
# Processing file 10_10_s.bmp
# Processing file 11_10_s.bmp
# Processing file 7_27_s.bmp
# Processing file 6_27_s.bmp
# Processing file 12_5_s.bmp
# Processing file 5_15_s.bmp
# Processing file 4_15_s.bmp
# Processing file 11_4_s.bmp
# Processing file 19_2_s.bmp
# Processing file 10_12_s.bmp
# Processing file 11_12_s.bmp
# Processing file 4_9_s.bmp
# Processing file 12_20_s.bmp
# Processing file 13_20_s.bmp
# Processing file 7_8_s.bmp
# Processing file 14_8_s.bmp
# Processing file 8_12_s.bmp
# Processing file 9_12_s.bmp
# Processing file 17_9_s.bmp
# Processing file 5_28_s.bmp
# Processing file 4_28_s.bmp
# Processing file 2_4_s.bmp
# Processing file 1_5_s.bmp
# Processing file 9_3_s.bmp
# Processing file 18_6_s.bmp
# Processing file 13_1_s.bmp
# Processing file 18_22_s.bmp
# Processing file 19_22_s.bmp
# Processing file 15_18_s.bmp
# Processing file 14_18_s.bmp
# Processing file 14_25_s.bmp
# Processing file 17_17_s.bmp
# Processing file 16_17_s.bmp
# Processing file 2_10_s.bmp
# Processing file 3_10_s.bmp
# Processing file 8_7_s.bmp
# Processing file 1_22_s.bmp
# Processing file 5_9_s.bmp
# Processing file 6_8_s.bmp
# Processing file 2_29_s.bmp
# Processing file 13_5_s.bmp
# Processing file 3_29_s.bmp
# Processing file 18_26_s.bmp
# Processing file 19_26_s.bmp
# Processing file 18_2_s.bmp
# Processing file 10_4_s.bmp
# Processing file 1_26_s.bmp
# Processing file 10_32_s.bmp
# Processing file 3_4_s.bmp
# Processing file 2_14_s.bmp
# Processing file 3_14_s.bmp
# Processing file 8_3_s.bmp
# Processing file 17_13_s.bmp
# Processing file 16_13_s.bmp
# Processing file 15_8_s.bmp
# Processing file 15_21_s.bmp
# Processing file 14_21_s.bmp
# Processing file 16_9_s.bmp
# Processing file 12_24_s.bmp
# Processing file 13_24_s.bmp
# Processing file 2_30_s.bmp
# Processing file 3_30_s.bmp
# Processing file 10_16_s.bmp
# Processing file 11_16_s.bmp
# Processing file 5_11_s.bmp
# Processing file 4_11_s.bmp
# Processing file 19_6_s.bmp
# Processing file 7_23_s.bmp
# Processing file 6_23_s.bmp
# Processing file 12_1_s.bmp
# Processing file 1_1_s.bmp
# Processing file 9_7_s.bmp
# Processing file 12_19_s.bmp
# Processing file 13_19_s.bmp
# Processing file 8_16_s.bmp
# Processing file 9_16_s.bmp
# Processing file 2_2_s.bmp
# Processing file 1_3_s.bmp
# Processing file 9_5_s.bmp
# Processing file 8_14_s.bmp
# Processing file 9_14_s.bmp
# Processing file 10_29_s.bmp
# Processing file 11_29_s.bmp
# Processing file 10_14_s.bmp
# Processing file 11_14_s.bmp
# Processing file 8_29_s.bmp
# Processing file 9_29_s.bmp
# Processing file 12_26_s.bmp
# Processing file 13_26_s.bmp
# Processing file 12_3_s.bmp
# Processing file 7_21_s.bmp
# Processing file 6_21_s.bmp
# Processing file 11_2_s.bmp
# Processing file 19_4_s.bmp
# Processing file 5_13_s.bmp
# Processing file 4_13_s.bmp
# Processing file 8_1_s.bmp
# Processing file 18_19_s.bmp
# Processing file 19_19_s.bmp
# Processing file 2_16_s.bmp
# Processing file 3_16_s.bmp
# Processing file 20_9_s.bmp
# Processing file 10_30_s.bmp
# Processing file 3_6_s.bmp
# Processing file 11_30_s.bmp
# Processing file 20_21_s.bmp
# Processing file 1_24_s.bmp
# Processing file 15_23_s.bmp
# Processing file 14_23_s.bmp
# Processing file 17_11_s.bmp
# Processing file 16_11_s.bmp
# Processing file 10_6_s.bmp
# Processing file 1_19_s.bmp
# Processing file 18_24_s.bmp
# Processing file 19_24_s.bmp
# Processing file 8_30_s.bmp
# Processing file 13_7_s.bmp
# Processing file 9_30_s.bmp
# Processing file 5_29_s.bmp
# Processing file 4_29_s.bmp
# Processing file 2_5_s.bmp
# Processing file 9_2_s.bmp
# Processing file 1_4_s.bmp
# Processing file 14_9_s.bmp
# Processing file 8_13_s.bmp
# Processing file 9_13_s.bmp
# Processing file 17_8_s.bmp
# Processing file 10_13_s.bmp
# Processing file 11_13_s.bmp
# Processing file 4_8_s.bmp
# Processing file 12_21_s.bmp
# Processing file 13_21_s.bmp
# Processing file 7_9_s.bmp
# Processing file 7_26_s.bmp
# Processing file 6_26_s.bmp
# Processing file 12_4_s.bmp
# Processing file 5_14_s.bmp
# Processing file 4_14_s.bmp
# Processing file 19_3_s.bmp
# Processing file 11_5_s.bmp
# Processing file 2_11_s.bmp
# Processing file 3_11_s.bmp
# Processing file 8_6_s.bmp
# Processing file 1_23_s.bmp
# Processing file 3_1_s.bmp
# Processing file 15_24_s.bmp
# Processing file 14_24_s.bmp
# Processing file 5_30_s.bmp
# Processing file 4_30_s.bmp
# Processing file 17_16_s.bmp
# Processing file 16_16_s.bmp
# Processing file 15_19_s.bmp
# Processing file 14_19_s.bmp
# Processing file 10_1_s.bmp
# Processing file 18_7_s.bmp
# Processing file 18_23_s.bmp
# Processing file 19_23_s.bmp
# Processing file 17_29_s.bmp
# Processing file 16_29_s.bmp
# Processing file 18_21_s.bmp
# Processing file 19_21_s.bmp
# Processing file 13_2_s.bmp
# Processing file 10_3_s.bmp
# Processing file 18_5_s.bmp
# Processing file 20_19_s.bmp
# Processing file 3_3_s.bmp
# Processing file 1_21_s.bmp
# Processing file 8_4_s.bmp
# Processing file 2_13_s.bmp
# Processing file 3_13_s.bmp
# Processing file 17_14_s.bmp
# Processing file 16_14_s.bmp
# Processing file 14_26_s.bmp
# Processing file 12_23_s.bmp
# Processing file 13_23_s.bmp
# Processing file 10_11_s.bmp
# Processing file 11_11_s.bmp
# Processing file 19_1_s.bmp
# Processing file 11_7_s.bmp
# Processing file 5_16_s.bmp
# Processing file 4_16_s.bmp
# Processing file 17_30_s.bmp
# Processing file 16_30_s.bmp
# Processing file 12_6_s.bmp
# Processing file 7_24_s.bmp
# Processing file 6_24_s.bmp
# Processing file 7_19_s.bmp
# Processing file 6_19_s.bmp
# Processing file 1_6_s.bmp
# Processing file 2_7_s.bmp
# Processing file 8_11_s.bmp
# Processing file 9_11_s.bmp
# Processing file 12_2_s.bmp
# Processing file 7_20_s.bmp
# Processing file 6_20_s.bmp
# Processing file 19_5_s.bmp
# Processing file 11_3_s.bmp
# Processing file 5_12_s.bmp
# Processing file 4_12_s.bmp
# Processing file 10_15_s.bmp
# Processing file 11_15_s.bmp
# Processing file 8_28_s.bmp
# Processing file 9_28_s.bmp
# Processing file 12_27_s.bmp
# Processing file 13_27_s.bmp
# Processing file 8_15_s.bmp
# Processing file 9_15_s.bmp
# Processing file 10_28_s.bmp
# Processing file 11_28_s.bmp
# Processing file 2_3_s.bmp
# Processing file 9_4_s.bmp
# Processing file 1_2_s.bmp
# Processing file 10_7_s.bmp
# Processing file 18_1_s.bmp
# Processing file 1_18_s.bmp
# Processing file 18_25_s.bmp
# Processing file 19_25_s.bmp
# Processing file 13_6_s.bmp
# Processing file 15_22_s.bmp
# Processing file 14_22_s.bmp
# Processing file 17_10_s.bmp
# Processing file 16_10_s.bmp
# Processing file 18_18_s.bmp
# Processing file 19_18_s.bmp
# Processing file 2_17_s.bmp
# Processing file 20_8_s.bmp
# Processing file 3_17_s.bmp
# Processing file 10_31_s.bmp
# Processing file 3_7_s.bmp
# Processing file 1_25_s.bmp
# Processing file 20_20_s.bmp
# Processing file 17_12_s.bmp
# Processing file 16_12_s.bmp
# Processing file 15_9_s.bmp
# Processing file 15_20_s.bmp
# Processing file 14_20_s.bmp
# Processing file 16_8_s.bmp
# Processing file 1_27_s.bmp
# Processing file 3_5_s.bmp
# Processing file 2_15_s.bmp
# Processing file 3_15_s.bmp
# Processing file 8_2_s.bmp
# Processing file 2_28_s.bmp
# Processing file 13_4_s.bmp
# Processing file 3_28_s.bmp
# Processing file 18_27_s.bmp
# Processing file 19_27_s.bmp
# Processing file 10_5_s.bmp
# Processing file 18_3_s.bmp
# Processing file 5_8_s.bmp
# Processing file 6_9_s.bmp
# Processing file 12_18_s.bmp
# Processing file 13_18_s.bmp
# Processing file 8_17_s.bmp
# Processing file 9_17_s.bmp
# Processing file 9_6_s.bmp
# Processing file 2_1_s.bmp
# Processing file 5_10_s.bmp
# Processing file 4_10_s.bmp
# Processing file 19_7_s.bmp
# Processing file 11_1_s.bmp
# Processing file 7_22_s.bmp
# Processing file 6_22_s.bmp
# Processing file 12_25_s.bmp
# Processing file 13_25_s.bmp
# Processing file 10_17_s.bmp
# Processing file 11_17_s.bmp
# Processing file 9_26_s.bmp
# Processing file 7_1_s.bmp
# Processing file 8_26_s.bmp
# Processing file 13_29_s.bmp
# Processing file 12_29_s.bmp
# Processing file 11_26_s.bmp
# Processing file 10_26_s.bmp
# Processing file 13_14_s.bmp
# Processing file 14_1_s.bmp
# Processing file 12_14_s.bmp
# Processing file 6_13_s.bmp
# Processing file 7_13_s.bmp
# Processing file 4_21_s.bmp
# Processing file 5_21_s.bmp
# Processing file 13_30_s.bmp
# Processing file 12_30_s.bmp
# Processing file 3_24_s.bmp
# Processing file 13_8_s.bmp
# Processing file 2_24_s.bmp
# Processing file 20_13_s.bmp
# Processing file 1_16_s.bmp
# Processing file 10_9_s.bmp
# Processing file 14_11_s.bmp
# Processing file 5_4_s.bmp
# Processing file 15_11_s.bmp
# Processing file 16_23_s.bmp
# Processing file 6_5_s.bmp
# Processing file 17_23_s.bmp
# Processing file 15_5_s.bmp
# Processing file 16_4_s.bmp
# Processing file 3_9_s.bmp
# Processing file 19_16_s.bmp
# Processing file 18_16_s.bmp
# Processing file 20_6_s.bmp
# Processing file 3_19_s.bmp
# Processing file 2_19_s.bmp
# Processing file 16_6_s.bmp
# Processing file 15_7_s.bmp
# Processing file 20_4_s.bmp
# Processing file 19_14_s.bmp
# Processing file 18_14_s.bmp
# Processing file 1_29_s.bmp
# Processing file 20_11_s.bmp
# Processing file 1_14_s.bmp
# Processing file 3_26_s.bmp
# Processing file 2_26_s.bmp
# Processing file 19_29_s.bmp
# Processing file 12_32_s.bmp
# Processing file 18_29_s.bmp
# Processing file 16_21_s.bmp
# Processing file 6_7_s.bmp
# Processing file 17_21_s.bmp
# Processing file 14_13_s.bmp
# Processing file 5_6_s.bmp
# Processing file 15_13_s.bmp
# Processing file 13_16_s.bmp
# Processing file 14_3_s.bmp
# Processing file 12_16_s.bmp
# Processing file 9_19_s.bmp
# Processing file 8_19_s.bmp
# Processing file 17_2_s.bmp
# Processing file 11_24_s.bmp
# Processing file 10_24_s.bmp
# Processing file 1_30_s.bmp
# Processing file 4_23_s.bmp
# Processing file 5_23_s.bmp
# Processing file 6_11_s.bmp
# Processing file 9_8_s.bmp
# Processing file 7_11_s.bmp
# Processing file 19_9_s.bmp
# Processing file 11_19_s.bmp
# Processing file 10_19_s.bmp
# Processing file 4_2_s.bmp
# Processing file 19_30_s.bmp
# Processing file 18_30_s.bmp
# Processing file 9_24_s.bmp
# Processing file 7_3_s.bmp
# Processing file 8_24_s.bmp
# Processing file 6_15_s.bmp
# Processing file 7_15_s.bmp
# Processing file 4_27_s.bmp
# Processing file 5_27_s.bmp
# Processing file 17_6_s.bmp
# Processing file 11_20_s.bmp
# Processing file 10_20_s.bmp
# Processing file 13_12_s.bmp
# Processing file 14_7_s.bmp
# Processing file 12_12_s.bmp
# Processing file 9_20_s.bmp
# Processing file 7_7_s.bmp
# Processing file 8_20_s.bmp
# Processing file 4_6_s.bmp
# Processing file 6_28_s.bmp
# Processing file 7_28_s.bmp
# Processing file 19_10_s.bmp
# Processing file 18_10_s.bmp
# Processing file 8_8_s.bmp
# Processing file 16_18_s.bmp
# Processing file 17_18_s.bmp
# Processing file 15_3_s.bmp
# Processing file 16_2_s.bmp
# Processing file 14_17_s.bmp
# Processing file 5_2_s.bmp
# Processing file 15_17_s.bmp
# Processing file 16_25_s.bmp
# Processing file 6_3_s.bmp
# Processing file 17_25_s.bmp
# Processing file 3_22_s.bmp
# Processing file 2_22_s.bmp
# Processing file 20_15_s.bmp
# Processing file 1_10_s.bmp
# Processing file 18_9_s.bmp
# Processing file 16_27_s.bmp
# Processing file 6_1_s.bmp
# Processing file 17_27_s.bmp
# Processing file 14_15_s.bmp
# Processing file 15_15_s.bmp
# Processing file 20_17_s.bmp
# Processing file 1_12_s.bmp
# Processing file 12_34_s.bmp
# Processing file 3_20_s.bmp
# Processing file 2_20_s.bmp
# Processing file 19_12_s.bmp
# Processing file 18_12_s.bmp
# Processing file 20_2_s.bmp
# Processing file 14_28_s.bmp
# Processing file 15_1_s.bmp
# Processing file 4_4_s.bmp
# Processing file 9_22_s.bmp
# Processing file 7_5_s.bmp
# Processing file 8_22_s.bmp
# Processing file 12_8_s.bmp
# Processing file 11_9_s.bmp
# Processing file 4_18_s.bmp
# Processing file 5_18_s.bmp
# Processing file 2_9_s.bmp
# Processing file 4_25_s.bmp
# Processing file 5_25_s.bmp
# Processing file 6_17_s.bmp
# Processing file 1_8_s.bmp
# Processing file 7_17_s.bmp
# Processing file 13_10_s.bmp
# Processing file 14_5_s.bmp
# Processing file 12_10_s.bmp
# Processing file 17_4_s.bmp
# Processing file 11_22_s.bmp
# Processing file 10_22_s.bmp
# Processing file 16_20_s.bmp
# Processing file 6_6_s.bmp
# Processing file 17_20_s.bmp
# Processing file 14_12_s.bmp
# Processing file 15_12_s.bmp
# Processing file 5_7_s.bmp
# Processing file 1_15_s.bmp
# Processing file 20_10_s.bmp
# Processing file 3_27_s.bmp
# Processing file 2_27_s.bmp
# Processing file 19_28_s.bmp
# Processing file 18_28_s.bmp
# Processing file 12_33_s.bmp
# Processing file 20_5_s.bmp
# Processing file 19_15_s.bmp
# Processing file 18_15_s.bmp
# Processing file 1_28_s.bmp
# Processing file 16_7_s.bmp
# Processing file 15_6_s.bmp
# Processing file 11_18_s.bmp
# Processing file 10_18_s.bmp
# Processing file 4_3_s.bmp
# Processing file 7_2_s.bmp
# Processing file 9_25_s.bmp
# Processing file 8_25_s.bmp
# Processing file 19_8_s.bmp
# Processing file 4_22_s.bmp
# Processing file 5_22_s.bmp
# Processing file 6_10_s.bmp
# Processing file 9_9_s.bmp
# Processing file 7_10_s.bmp
# Processing file 14_2_s.bmp
# Processing file 13_17_s.bmp
# Processing file 12_17_s.bmp
# Processing file 9_18_s.bmp
# Processing file 8_18_s.bmp
# Processing file 17_3_s.bmp
# Processing file 11_25_s.bmp
# Processing file 10_25_s.bmp
# Processing file 6_12_s.bmp
# Processing file 7_12_s.bmp
# Processing file 4_20_s.bmp
# Processing file 5_20_s.bmp
# Processing file 17_1_s.bmp
# Processing file 11_27_s.bmp
# Processing file 10_27_s.bmp
# Processing file 13_15_s.bmp
# Processing file 12_15_s.bmp
# Processing file 9_27_s.bmp
# Processing file 8_27_s.bmp
# Processing file 13_28_s.bmp
# Processing file 12_28_s.bmp
# Processing file 4_1_s.bmp
# Processing file 3_8_s.bmp
# Processing file 19_17_s.bmp
# Processing file 18_17_s.bmp
# Processing file 3_18_s.bmp
# Processing file 20_7_s.bmp
# Processing file 2_18_s.bmp
# Processing file 15_4_s.bmp
# Processing file 16_5_s.bmp
# Processing file 14_10_s.bmp
# Processing file 15_10_s.bmp
# Processing file 5_5_s.bmp
# Processing file 16_22_s.bmp
# Processing file 6_4_s.bmp
# Processing file 17_22_s.bmp
# Processing file 12_31_s.bmp
# Processing file 3_25_s.bmp
# Processing file 13_9_s.bmp
# Processing file 2_25_s.bmp
# Processing file 1_17_s.bmp
# Processing file 20_12_s.bmp
# Processing file 10_8_s.bmp
# Processing file 16_1_s.bmp
# Processing file 14_29_s.bmp
# Processing file 19_13_s.bmp
# Processing file 18_13_s.bmp
# Processing file 20_3_s.bmp
# Processing file 1_13_s.bmp
# Processing file 20_16_s.bmp
# Processing file 3_21_s.bmp
# Processing file 2_21_s.bmp
# Processing file 16_26_s.bmp
# Processing file 17_26_s.bmp
# Processing file 14_14_s.bmp
# Processing file 15_14_s.bmp
# Processing file 5_1_s.bmp
# Processing file 14_4_s.bmp
# Processing file 13_11_s.bmp
# Processing file 12_11_s.bmp
# Processing file 17_5_s.bmp
# Processing file 11_23_s.bmp
# Processing file 10_23_s.bmp
# Processing file 14_30_s.bmp
# Processing file 2_8_s.bmp
# Processing file 4_24_s.bmp
# Processing file 5_24_s.bmp
# Processing file 1_9_s.bmp
# Processing file 6_16_s.bmp
# Processing file 7_16_s.bmp
# Processing file 12_9_s.bmp
# Processing file 11_8_s.bmp
# Processing file 4_19_s.bmp
# Processing file 5_19_s.bmp
# Processing file 4_5_s.bmp
# Processing file 7_4_s.bmp
# Processing file 9_23_s.bmp
# Processing file 8_23_s.bmp
# Processing file 6_29_s.bmp
# Processing file 7_29_s.bmp
# Processing file 7_6_s.bmp
# Processing file 9_21_s.bmp
# Processing file 8_21_s.bmp
# Processing file 4_7_s.bmp
# Processing file 17_7_s.bmp
# Processing file 11_21_s.bmp
# Processing file 10_21_s.bmp
# Processing file 14_6_s.bmp
# Processing file 13_13_s.bmp
# Processing file 12_13_s.bmp
# Processing file 6_14_s.bmp
# Processing file 7_14_s.bmp
# Processing file 4_26_s.bmp
# Processing file 5_26_s.bmp
# Processing file 3_23_s.bmp
# Processing file 2_23_s.bmp
# Processing file 1_11_s.bmp
# Processing file 20_14_s.bmp
# Processing file 18_8_s.bmp
# Processing file 14_16_s.bmp
# Processing file 15_16_s.bmp
# Processing file 5_3_s.bmp
# Processing file 16_24_s.bmp
# Processing file 6_2_s.bmp
# Processing file 17_24_s.bmp
# Processing file 6_30_s.bmp
# Processing file 7_30_s.bmp
# Processing file 16_19_s.bmp
# Processing file 17_19_s.bmp
# Processing file 15_2_s.bmp
# Processing file 16_3_s.bmp
# Processing file 20_1_s.bmp
# Processing file 19_11_s.bmp
# Processing file 8_9_s.bmp
# Processing file 18_11_s.bmp
# Successfully Created Global HSV Color Descriptors

# %%
def load_descriptors(image_folder, descriptor_folder, descriptor_subfolder):
    ALLFEAT = []
    ALLFILES = []
    for filename in os.listdir(os.path.join(descriptor_folder, descriptor_subfolder)):
        if filename.endswith('.mat'):
            img_path = os.path.join(descriptor_folder, descriptor_subfolder, filename)
            img_actual_path = os.path.join(image_folder, 'Images', filename.replace(".mat", ".bmp"))
            img_data = sio.loadmat(img_path)
            ALLFILES.append(img_actual_path)
            ALLFEAT.append(img_data['F'].flatten())  # Ensure 1D
    return ALLFILES, np.array(ALLFEAT)

# %%
def cvpr_compare(F1, F2, dist_type='L2'):
    if dist_type == 'L2':
        return np.linalg.norm(F1 - F2)
    elif dist_type == 'L1':
        return np.sum(np.abs(F1 - F2))
    elif dist_type == 'Chi2':
        return np.sum(((F1 - F2)**2) / (F1 + F2 + 1e-10))
    elif dist_type == 'Cosine':
        return 1 - np.dot(F1, F2) / (np.linalg.norm(F1) * np.linalg.norm(F2) + 1e-10)
    elif dist_type == 'Mahalanobis':
        diff = F1 - F2
        return np.sqrt(np.dot(np.dot(diff, cov_inv), diff))  # cov_inv from phase 4

# %%
def extract_class_from_filename(file_path):
    filename = os.path.basename(file_path)
    parts = filename.split('_')
    class_no = int(parts[0])
    return class_no

# %%
def evaluate_pr_auc(response_class, query_class, all_classes_true, all_classes_pred, fig_title):
    precisions, recalls, _ = precision_recall_curve(response_class == query_class, np.ones(len(response_class)))
    ap = average_precision_score(response_class == query_class, np.ones(len(response_class)))
    f1 = f1_score(all_classes_true, all_classes_pred, average='macro')
    cm = confusion_matrix(all_classes_true, all_classes_pred)
    plt.plot(recalls, precisions, label=f'AP={ap:.3f}')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve for ' + fig_title)
    plt.legend()
    plt.savefig(fig_title + '.png')
    plt.show()
    return ap, f1, cm

# %%
# Req1 experiments
quant_levels = [4,8,16,32,48]
results_req1 = {'Q': [], 'AUC/AP': [], 'F1': []}
for Q in quant_levels:
    ALLFILES, FEAT = load_descriptors(DATASET_FOLDER, OUT_FOLDER, OUT_SUBFOLDER)
    query_image = os.path.join(DATASET_FOLDER, '7_9_s.bmp')
    position = ALLFILES.index(query_image)
    query = FEAT[position]
    dst = [(cvpr_compare(query, FEAT[i]), i) for i in range(len(FEAT))]
    dst.sort()
    response_class_no = [extract_class_from_filename(ALLFILES[dst[j][1]]) for j in range(len(ALLFILES))]
    query_class = response_class_no[0]
    response_class = np.array(response_class_no[1:])
    all_classes_true = [extract_class_from_filename(f) for f in ALLFILES[1:]]
    all_classes_pred = response_class
    fig_title = f'pr_q{Q}'
    ap, f1, cm = evaluate_pr_auc(response_class, query_class, all_classes_true, all_classes_pred, fig_title)
    results_req1['Q'].append(Q)
    results_req1['AUC/AP'].append(ap)
    results_req1['F1'].append(f1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 5
#       3 results_req1 = {'Q': [], 'AUC/AP': [], 'F1': []}
#       4 for Q in quant_levels:
# ----> 5     ALLFILES, FEAT = load_descriptors(DATASET_FOLDER, OUT_FOLDER, OUT_SUBFOLDER)
#       6     query_image = os.path.join(DATASET_FOLDER, '7_9_s.bmp')
#       7     position = ALLFILES.index(query_image)
#
# Cell In[10], line 11, in load_descriptors(image_folder, descriptor_folder, descriptor_subfolder)
#       9         ALLFILES.append(img_actual_path)
#      10         ALLFEAT.append(img_data['F'].flatten())  # Ensure 1D
# ---> 11 return ALLFILES, np.array(ALLFEAT)
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (591,) + inhomogeneous part.

# %%
# Req3 grid + LBP
def grid_lbp_descriptor(img, Q_color, grid_size=3, lbp_points=16):
    h, w, _ = img.shape
    cell_h, cell_w = h // grid_size, w // grid_size
    desc = []
    for i in range(grid_size):
        for j in range(grid_size):
            cell = img[i*cell_h:(i+1)*cell_h, j*cell_w:(j+1)*cell_w]
            hist = extract_global_hsv_hist(cell, Q_color)
            desc.append(hist)
            gray = cv2.cvtColor((cell*255).astype(np.uint8), cv2.COLOR_RGB2GRAY)
            lbp = local_binary_pattern(gray, lbp_points, 3, method='uniform')
            lbp_hist, _ = np.histogram(lbp.ravel(), bins=np.arange(0, lbp_points + 3))
            lbp_hist = lbp_hist.astype("float") / (lbp_hist.sum() + 1e-7)
            desc.append(lbp_hist)
    return np.concatenate(desc)

# %%
def compute_and_save_grid_lbp(Q_color, lbp_points, dataset_folder, out_folder, out_subfolder):
    os.makedirs(os.path.join(out_folder, out_subfolder), exist_ok=True)
    for img_path in glob.glob(os.path.join(dataset_folder, 'Images', '*.bmp')):
        filename = os.path.basename(img_path)
        img = cv2.imread(img_path).astype(np.float64) / 255.0
        F = grid_lbp_descriptor(img, Q_color, lbp_points=lbp_points)
        fout = os.path.join(out_folder, out_subfolder, filename.replace('.bmp', '.mat'))
        sio.savemat(fout, {'F': F})
    print("Successfully Created Grid HSV + LBP Descriptors")

# %%
compute_and_save_grid_lbp(32, 16, DATASET_FOLDER, OUT_FOLDER, OUT_SUBFOLDER_GRID)
ALLFILES, FEAT = load_descriptors(DATASET_FOLDER, OUT_FOLDER, OUT_SUBFOLDER_GRID)
query_image = os.path.join(DATASET_FOLDER, 'Images', '7_9_s.bmp')
position = ALLFILES.index(query_image)
query = FEAT[position]
dst = [(cvpr_compare(query, FEAT[i]), i) for i in range(len(FEAT))]
dst.sort()
response_class = [extract_class_from_filename(ALLFILES[d[1]]) for d in dst[1:]]
query_class = extract_class_from_filename(query_image)
y_true = np.array([cls == query_class for cls in response_class])
fig_title = 'pr_grid_lbp16'
ap, f1, cm = evaluate_pr_auc(y_true, query_class, response_class, response_class, fig_title)

# %%
# Req4: PCA + Mahalanobis
FEAT_reduced, pca = apply_pca(FEAT)
cov = EmpiricalCovariance().fit(FEAT_reduced)
cov_inv = np.linalg.pinv(cov.covariance_)
query_reduced = FEAT_reduced[position]
dst = [(cvpr_compare(query_reduced, FEAT_reduced[i], 'Mahalanobis', cov_inv), i) for i in range(len(FEAT_reduced))]
dst.sort()
response_class = [extract_class_from_filename(ALLFILES[d[1]]) for d in dst[1:]]
query_class = extract_class_from_filename(query_image)
y_true = np.array([cls == query_class for cls in response_class])
fig_title = 'pr_pca_mahal'
ap, f1, cm = evaluate_pr_auc(y_true, query_class, response_class, response_class, fig_title)

# %%
subfolder = compute_and_save_bovw(100, DATASET_FOLDER, OUT_FOLDER, OUT_SUBFOLDER_BOVW)
ALLFILES, FEAT = load_descriptors(DATASET_FOLDER, OUT_FOLDER, subfolder)
query_image = os.path.join(DATASET_FOLDER, 'Images', '7_9_s.bmp')
position = ALLFILES.index(query_image)
query = FEAT[position]
dst = [(cvpr_compare(query, FEAT[i], 'Chi2'), i) for i in range(len(FEAT))]
dst.sort()
response_class = [extract_class_from_filename(ALLFILES[d[1]]) for d in dst[1:]]
query_class = extract_class_from_filename(query_image)
y_true = np.array([cls == query_class for cls in response_class])
fig_title = 'pr_bovw100'
ap, f1, cm = evaluate_pr_auc(y_true, query_class, response_class, response_class, fig_title)
